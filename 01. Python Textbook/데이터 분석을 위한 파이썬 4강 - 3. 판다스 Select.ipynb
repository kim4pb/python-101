# %%
import pandas as pd
data=pd.read_csv('kr_googlestore.csv')

# %% [markdown]
# # 3. **데이터 선택**

# %% [markdown]
# ### a. 특정 '컬럼'의 값 가져오기
#
# **데이터에서 특정 컬럼의 값만 선택해서 사용하고 싶을 수 있어요 그럴 땐 이렇게 인덱싱 하면 됩니다.**

# %%
data['어플']
# Out:
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                   Coloring book moana
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                 Sketch - Draw & Paint
# 4                 Pixel Draw - Number Art Coloring Book
#                             ...
# 95    All of the parking lot - National Park applica...
# 96                 Inquiry Fines and Debits of Vehicles
# 97                                          Gas Station
# 98                                Hush - Beauty for 전체가
# 99                       ipsy: Makeup, Beauty, and Tips
# Name: 어플, Length: 100, dtype: object

# %%
data.어플
# Out:
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                   Coloring book moana
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                 Sketch - Draw & Paint
# 4                 Pixel Draw - Number Art Coloring Book
#                             ...
# 95    All of the parking lot - National Park applica...
# 96                 Inquiry Fines and Debits of Vehicles
# 97                                          Gas Station
# 98                                Hush - Beauty for 전체가
# 99                       ipsy: Makeup, Beauty, and Tips
# Name: 어플, Length: 100, dtype: object

# %% [markdown]
# 한 개 이상의 컬럼을 동시에 보고 싶을 때는 컬럼명을 리스트로 감싸서 인덱싱 해주세요.

# %%
data[['어플', '설치 수', '리뷰 수']]
# Out:
#                                                    어플      설치 수    리뷰 수
# 0      Photo Editor & Candy Camera & Grid & ScrapBook     10000     159
# 1                                 Coloring book moana    500000     967
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...   5000000   87510
# 3                               Sketch - Draw & Paint  50000000  215644
# 4               Pixel Draw - Number Art Coloring Book    100000     967
# ..                                                ...       ...     ...
# 95  All of the parking lot - National Park applica...    500000    1754
# 96               Inquiry Fines and Debits of Vehicles    500000    2680
# 97                                        Gas Station    100000    1288
# 98                              Hush - Beauty for 전체가    500000   18900
# 99                     ipsy: Makeup, Beauty, and Tips   1000000   49790
#
# [100 rows x 3 columns]

# %% [markdown]
# ### b. 슬라이싱
#
#
# 리스트를 슬라이싱하듯이, 판다스 데이터프레임도 행으로 슬라이싱을 할 수 있습니다.

# %%
# 맨 처음 5개의 행을 선택하기

data[0:5]
# Out:
#                                                   어플  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                Coloring book moana
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                              Sketch - Draw & Paint
# 4              Pixel Draw - Number Art Coloring Book
#
#                           장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 0               Art & Design  4.1     159  190.0     10000  무료  0  전체가
# 1  Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2               Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3               Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4    Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
#
#    안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 0       4.0     2018       1  2018.01
# 1       4.0     2018       1  2018.01
# 2       4.0     2018       8  2018.08
# 3       4.2     2018       6  2018.06
# 4       4.4     2018       6  2018.06

# %%
# index가 [12:15]에 해당하는 것만 가져오기
data[12:15]
# Out:
#                                                  어플            장르   등급   리뷰 수  \
# 12                   Tattoo Name On My Photo Editor  Art & Design  NaN  44829
# 13                            Mandala Coloring Book  Art & Design  4.6   4326
# 14  3D Color Pixel by Number - Sandbox Art Coloring  Art & Design  NaN   1518
#
#        크기      설치 수  타입     가격  연령층  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 12  200.0  10000000  무료      0  청소년       4.1     2018       4  2018.04
# 13  210.0    100000  무료      0  전체가       4.4     2018       6  2018.06
# 14  370.0    100000  유료  $1.99  전체가       2.3     2018       8  2018.08

# %% [markdown]
# <br>
#
# **특정 컬럼을 정해서 슬라이싱 해서 정보를 선택할 수도 있죠.**

# %%
data2 = data[['어플','가격']][0:10]

# %%
print(data2)
# Out:
#                                                   어플     가격
# 0     Photo Editor & Candy Camera & Grid & ScrapBook      0
# 1                                Coloring book moana      0
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...      0
# 3                              Sketch - Draw & Paint      0
# 4              Pixel Draw - Number Art Coloring Book      0
# 5                         Paper flowers instructions      0
# 6            Smoke Effect Photo Maker - Smoke Editor      0
# 7                                   Infinite Painter  $4.99
# 8                               Garden Coloring Book      0
# 9                      Kids Paint Free - Drawing Fun      0

# %% [markdown]
# <br>
#
# ### c .loc을 통한 인덱싱
#
# 참고 : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html#pandas.DataFrame.loc

# %% [markdown]
# 1. 인자가 하나일 때는 **인덱스**로 접근
#
#         .loc[x]
#         .loc[[x, x1]]
#         .loc[[x : x1]]
#
#
# 2. 인자를 2개 받을 경우 **인덱스**와 **컬럼명**으로 접근
#
#         .loc[x : y]
#         .loc[[x, x1, x2], y]
#
#
# 3. 첫 인자를 :로 놓고 컬럼명으로 접근
#
#         .loc[:,y]

# %%
data.loc[3]
#data.loc[App['Tattoo Name On My Photo Editor']]
# Out:
# 어플          Sketch - Draw & Paint
# 장르                   Art & Design
# 등급                            4.5
# 리뷰 수                       215644
# 크기                            250
# 설치 수                     50000000
# 타입                             무료
# 가격                              0
# 연령층                           청소년
# 안드로이드 버전                      4.2
# 업데이트_년도                      2018
# 업데이트_달                          6
# 업데이트_년달                   2018.06
# Name: 3, dtype: object

# %%
# 컬럼 App, Rating에 대한 모든 값 가져오기
data.loc[:, ['어플', '등급']]
# Out:
#                                                    어플   등급
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  4.1
# 1                                 Coloring book moana  3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  4.7
# 3                               Sketch - Draw & Paint  4.5
# 4               Pixel Draw - Number Art Coloring Book  4.3
# ..                                                ...  ...
# 95  All of the parking lot - National Park applica...  4.0
# 96               Inquiry Fines and Debits of Vehicles  NaN
# 97                                        Gas Station  4.0
# 98                              Hush - Beauty for 전체가  4.7
# 99                     ipsy: Makeup, Beauty, and Tips  NaN
#
# [100 rows x 2 columns]

# %% [markdown]
# #### 특정 인덱스 값의 컬럼 App, Rating에 대한 모든 값 가져오기

# %%
data.loc[10, ['어플', '등급', '설치 수']]
# Out:
# 어플      Text on Photo - Fonteee
# 등급                          4.4
# 설치 수                    1000000
# Name: 10, dtype: object

# %% [markdown]
# #### .at[ x, y ]  : 특정 인덱스 값과 특정 컬럼에 있는 값 가져오기

# %%
data.loc[[5],'어플'] #object타입으로 메타데이터도 가져온다.
# Out:
# 5    Paper flowers instructions
# Name: 어플, dtype: object

# %%
data.at[5, '어플'] # string으로 값만 반환
# Out:
# 'Paper flowers instructions'

# %% [markdown]
# ### d. .iloc : **위치 이용하여 선택하기**
#
# .iloc 매서드는 정수 위치를 이용해서 데이터에 접근

# %%
# python 인덱스 개념. 즉, 5번째 인덱스를 가져오는 게 아닌 6번째 인덱스 get 
data.iloc[5]
# Out:
# 어플          Paper flowers instructions
# 장르                        Art & Design
# 등급                                 4.4
# 리뷰 수                               167
# 크기                                 5.6
# 설치 수                             50000
# 타입                                  무료
# 가격                                   0
# 연령층                                전체가
# 안드로이드 버전                           2.3
# 업데이트_년도                           2017
# 업데이트_달                               3
# 업데이트_년달                        2017.03
# Name: 5, dtype: object

# %%
# 데이터 슬라이싱 및 인덱스
data.iloc[3:5,0:2]
# Out:
#                                       어플                       장르
# 3                  Sketch - Draw & Paint             Art & Design
# 4  Pixel Draw - Number Art Coloring Book  Art & Design;Creativity

# %%
# 데이터 슬라이싱 및 인덱스
data.iloc[[1,2,4],[0,2]]
# Out:
#                                                   어플   등급
# 1                                Coloring book moana  3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  4.7
# 4              Pixel Draw - Number Art Coloring Book  4.3

# %%
# 명시적으로 행이나 열 선택 인자에 ' : ' 있으면 -> 행 or 열 전체 가져와라
data.iloc[1:5,:]
# data.iloc[:,1:5]
# Out:
#                                                   어플  \
# 1                                Coloring book moana
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                              Sketch - Draw & Paint
# 4              Pixel Draw - Number Art Coloring Book
#
#                           장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 1  Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2               Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3               Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4    Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
#
#    안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 1       4.0     2018       1  2018.01
# 2       4.0     2018       8  2018.08
# 3       4.2     2018       6  2018.06
# 4       4.4     2018       6  2018.06

# %%
# 값 하나를 선택하기 위해 특정 행과 열 지정
data.iloc[4,2]
# Out:
# 4.3

# %%
data.iat[4,2]
# Out:
# 4.3

# %% [markdown]
# ### 5) 조건 이용 선택
#
# #### 등급이 3.7 이상인 데이터만 선택해서 보고 싶을 땐 어떻게 해야할까요?

# %%
data[data.등급 > 3.7]
# Out:
#                                                    어플  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                 Coloring book moana
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                               Sketch - Draw & Paint
# 4               Pixel Draw - Number Art Coloring Book
# ..                                                ...
# 93                                         auto fines
# 94  Used car is the first car - used car purchase,...
# 95  All of the parking lot - National Park applica...
# 97                                        Gas Station
# 98                              Hush - Beauty for 전체가
#
#                            장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 0                Art & Design  4.1     159  190.0     10000  무료  0  전체가
# 1   Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2                Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3                Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4     Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
# ..                        ...  ...     ...    ...       ...  .. ..  ...
# 93            Auto & Vehicles  4.6   31433  170.0   1000000  무료  0  전체가
# 94            Auto & Vehicles  4.6    5097  190.0   1000000  무료  0  전체가
# 95            Auto & Vehicles  4.0    1754  140.0    500000  무료  0  전체가
# 97            Auto & Vehicles  4.0    1288    4.5    100000  무료  0  전체가
# 98                     Beauty  4.7   18900  170.0    500000  무료  0  전체가
#
#     안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 0        4.0     2018       1  2018.01
# 1        4.0     2018       1  2018.01
# 2        4.0     2018       8  2018.08
# 3        4.2     2018       6  2018.06
# 4        4.4     2018       6  2018.06
# ..       ...      ...     ...      ...
# 93       4.0     2018       8  2018.08
# 94       4.0     2018       7  2018.07
# 95       4.0     2018       6  2018.06
# 97       4.0     2018       4  2018.04
# 98       5.0     2018       8  2018.08
#
# [79 rows x 13 columns]

# %% [markdown]
# #### 유료 어플들만 모아서 복사한 데이터를 만들어볼까요?

# %%
paa = data[data.타입 == '유료']

# %% [markdown]
# #### 이렇게 선택한 데이터를 다른 이름으로 변수를 만들어 주면, 이것은 원본 데이터에서 떨어져 나온 복사본 데이터가 됩니다

# %%
paa
# Out:
#                                                    어플  \
# 7                                    Infinite Painter
# 14    3D Color Pixel by Number - Sandbox Art Coloring
# 23                             Mcqueen Coloring pages
# 31                                  Art Drawing Ideas
# 32                          Anime Manga Coloring Book
# 33                                 Easy Origami Ideas
# 34                                    I Creative Idea
# 35                   How to draw Ladybug and Cat Noir
# 36     UNICORN - Color By Number & Pixel Art Coloring
# 37                                 Floor Plan Creator
# 38                     PIP Camera - PIP Collage Maker
# 39      How To Color Disney Princess - Coloring Pages
# 40                      Drawing Clothes Fashion Ideas
# 41                       Sad Poetry Photo Frames 2018
# 42                         Textgram - write on photos
# 43                                      Paint Splash!
# 59  REG - Check the regnumber, find information ab...
# 60                                       CityBus Lviv
# 61                     CDL Practice Test 2018 Edition
# 62  ezETC (ETC balance inquiry, meter trial, real-...
# 63                      Free VIN Report for Used Cars
# 64              DMV Permit Practice Test 2018 Edition
# 65                                  Check Vehicle Tax
# 66                                   Used Cars Mexico
# 67                                 Ulysse Speedometer
# 68                                             REPUVE
# 69                        Used cars for sale - Trovit
# 70  Fines of the State Traffic Safety Inspectorate...
# 71            SK Enca Direct Malls - Used Cars Search
#
#                                  장르   등급    리뷰 수     크기      설치 수  타입      가격  \
# 7                      Art & Design  4.1   36815  290.0   1000000  유료   $4.99
# 14                     Art & Design  NaN    1518  370.0    100000  유료   $1.99
# 23  Art & Design;Action & Adventure  NaN      61    7.0    100000  유료   $4.29
# 31                     Art & Design  4.1     227    5.2     50000  유료   $0.99
# 32                     Art & Design  NaN    5035  110.0    100000  유료   $1.99
# 33                     Art & Design  4.2    1015  110.0    100000  유료   $1.10
# 34                     Art & Design  4.7     353    4.2     10000  유료   $1.18
# 35                     Art & Design  3.8     564    9.2    100000  유료   $1.54
# 36          Art & Design;Creativity  4.7    8145  240.0    500000  유료   $4.99
# 37                     Art & Design  4.1   36639    NaN   5000000  유료   $4.99
# 38                     Art & Design  NaN     158  110.0     10000  유료   $4.99
# 39                     Art & Design  4.0     591    9.4    500000  유료  $54.55
# 40                     Art & Design  4.2     117  150.0     10000  유료   $4.99
# 41                     Art & Design  4.5     176  100.0    100000  유료   $3.61
# 42                     Art & Design  4.4  295221    NaN  10000000  유료   $4.99
# 43          Art & Design;Creativity  3.8    2206    1.2    100000  유료  $15.46
# 59                  Auto & Vehicles  3.9    3971    3.6    100000  유료   $0.99
# 60                  Auto & Vehicles  NaN     534    5.7     10000  유료   $4.25
# 61                  Auto & Vehicles  4.9    7774  170.0    100000  유료   $9.75
# 62                  Auto & Vehicles  4.3   38846    8.6   1000000  유료   $1.18
# 63                  Auto & Vehicles  4.6    2431    2.4    100000  유료   $2.54
# 64                  Auto & Vehicles  4.9    6090  270.0    100000  유료  $15.46
# 65                  Auto & Vehicles  3.9     295    2.7     10000  유료  $17.99
# 66                  Auto & Vehicles  4.0     190    2.5     50000  유료   $4.99
# 67                  Auto & Vehicles  4.3   40211    NaN   5000000  유료  $54.55
# 68                  Auto & Vehicles  3.9     356    NaN    100000  유료  $10.57
# 69                  Auto & Vehicles  4.2   52530    7.0   5000000  유료   $5.68
# 70                  Auto & Vehicles  4.8  116986  350.0   5000000  유료   $4.99
# 71                  Auto & Vehicles  NaN    1379  160.0    500000  유료   $1.58
#
#     연령층  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 7   전체가       4.2     2018       6  2018.06
# 14  전체가       2.3     2018       8  2018.08
# 23  전체가       4.1     2018       3  2018.03
# 31  전체가       2.3     2018       5  2018.05
# 32  전체가       4.0     2018       7  2018.07
# 33  전체가       4.1     2018       1  2018.01
# 34  청소년       4.1     2018       4  2018.04
# 35  전체가       4.1     2018       7  2018.07
# 36  전체가       4.4     2018       8  2018.08
# 37  전체가       2.3     2018       7  2018.07
# 38  전체가       4.0     2017      11  2017.11
# 39  전체가       4.0     2018       3  2018.03
# 40  전체가       4.0     2018       7  2018.07
# 41  전체가       4.0     2018       4  2018.04
# 42  전체가       4.0     2018       7  2018.07
# 43  전체가       4.1     2018       4  2018.04
# 59  전체가       4.4     2018       7  2018.07
# 60  전체가       4.0     2018       7  2018.07
# 61  전체가       4.2     2018       7  2018.07
# 62  전체가       4.1     2018       7  2018.07
# 63  전체가       4.0     2018       6  2018.06
# 64  전체가       4.2     2018       7  2018.07
# 65  전체가       4.4     2018       7  2018.07
# 66  전체가       2.3     2016      10  2016.10
# 67  전체가       2.3     2018       7  2018.07
# 68  전체가       2.3     2018       5  2018.05
# 69  전체가       4.0     2018       7  2018.07
# 70  전체가       4.0     2018       8  2018.08
# 71  전체가       4.2     2018       8  2018.08

# %% [markdown]
# #### 이 중에서 업데이트 년도가 2018년 이후인 것들만 보고 싶어요.

# %%
paa[paa['업데이트_년도'] >= 2018]
# Out:
#                                                    어플  \
# 7                                    Infinite Painter
# 14    3D Color Pixel by Number - Sandbox Art Coloring
# 23                             Mcqueen Coloring pages
# 31                                  Art Drawing Ideas
# 32                          Anime Manga Coloring Book
# 33                                 Easy Origami Ideas
# 34                                    I Creative Idea
# 35                   How to draw Ladybug and Cat Noir
# 36     UNICORN - Color By Number & Pixel Art Coloring
# 37                                 Floor Plan Creator
# 39      How To Color Disney Princess - Coloring Pages
# 40                      Drawing Clothes Fashion Ideas
# 41                       Sad Poetry Photo Frames 2018
# 42                         Textgram - write on photos
# 43                                      Paint Splash!
# 59  REG - Check the regnumber, find information ab...
# 60                                       CityBus Lviv
# 61                     CDL Practice Test 2018 Edition
# 62  ezETC (ETC balance inquiry, meter trial, real-...
# 63                      Free VIN Report for Used Cars
# 64              DMV Permit Practice Test 2018 Edition
# 65                                  Check Vehicle Tax
# 67                                 Ulysse Speedometer
# 68                                             REPUVE
# 69                        Used cars for sale - Trovit
# 70  Fines of the State Traffic Safety Inspectorate...
# 71            SK Enca Direct Malls - Used Cars Search
#
#                                  장르   등급    리뷰 수     크기      설치 수  타입      가격  \
# 7                      Art & Design  4.1   36815  290.0   1000000  유료   $4.99
# 14                     Art & Design  NaN    1518  370.0    100000  유료   $1.99
# 23  Art & Design;Action & Adventure  NaN      61    7.0    100000  유료   $4.29
# 31                     Art & Design  4.1     227    5.2     50000  유료   $0.99
# 32                     Art & Design  NaN    5035  110.0    100000  유료   $1.99
# 33                     Art & Design  4.2    1015  110.0    100000  유료   $1.10
# 34                     Art & Design  4.7     353    4.2     10000  유료   $1.18
# 35                     Art & Design  3.8     564    9.2    100000  유료   $1.54
# 36          Art & Design;Creativity  4.7    8145  240.0    500000  유료   $4.99
# 37                     Art & Design  4.1   36639    NaN   5000000  유료   $4.99
# 39                     Art & Design  4.0     591    9.4    500000  유료  $54.55
# 40                     Art & Design  4.2     117  150.0     10000  유료   $4.99
# 41                     Art & Design  4.5     176  100.0    100000  유료   $3.61
# 42                     Art & Design  4.4  295221    NaN  10000000  유료   $4.99
# 43          Art & Design;Creativity  3.8    2206    1.2    100000  유료  $15.46
# 59                  Auto & Vehicles  3.9    3971    3.6    100000  유료   $0.99
# 60                  Auto & Vehicles  NaN     534    5.7     10000  유료   $4.25
# 61                  Auto & Vehicles  4.9    7774  170.0    100000  유료   $9.75
# 62                  Auto & Vehicles  4.3   38846    8.6   1000000  유료   $1.18
# 63                  Auto & Vehicles  4.6    2431    2.4    100000  유료   $2.54
# 64                  Auto & Vehicles  4.9    6090  270.0    100000  유료  $15.46
# 65                  Auto & Vehicles  3.9     295    2.7     10000  유료  $17.99
# 67                  Auto & Vehicles  4.3   40211    NaN   5000000  유료  $54.55
# 68                  Auto & Vehicles  3.9     356    NaN    100000  유료  $10.57
# 69                  Auto & Vehicles  4.2   52530    7.0   5000000  유료   $5.68
# 70                  Auto & Vehicles  4.8  116986  350.0   5000000  유료   $4.99
# 71                  Auto & Vehicles  NaN    1379  160.0    500000  유료   $1.58
#
#     연령층  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 7   전체가       4.2     2018       6  2018.06
# 14  전체가       2.3     2018       8  2018.08
# 23  전체가       4.1     2018       3  2018.03
# 31  전체가       2.3     2018       5  2018.05
# 32  전체가       4.0     2018       7  2018.07
# 33  전체가       4.1     2018       1  2018.01
# 34  청소년       4.1     2018       4  2018.04
# 35  전체가       4.1     2018       7  2018.07
# 36  전체가       4.4     2018       8  2018.08
# 37  전체가       2.3     2018       7  2018.07
# 39  전체가       4.0     2018       3  2018.03
# 40  전체가       4.0     2018       7  2018.07
# 41  전체가       4.0     2018       4  2018.04
# 42  전체가       4.0     2018       7  2018.07
# 43  전체가       4.1     2018       4  2018.04
# 59  전체가       4.4     2018       7  2018.07
# 60  전체가       4.0     2018       7  2018.07
# 61  전체가       4.2     2018       7  2018.07
# 62  전체가       4.1     2018       7  2018.07
# 63  전체가       4.0     2018       6  2018.06
# 64  전체가       4.2     2018       7  2018.07
# 65  전체가       4.4     2018       7  2018.07
# 67  전체가       2.3     2018       7  2018.07
# 68  전체가       2.3     2018       5  2018.05
# 69  전체가       4.0     2018       7  2018.07
# 70  전체가       4.0     2018       8  2018.08
# 71  전체가       4.2     2018       8  2018.08

# %% [markdown]
# 이런 식으로 보고 싶은 데이터의 범위를 줄여가며 체크할 수도 있어요
