# %% [markdown]
# # 4강. 판다스로 데이터 살펴보기
# ------------

# %%
# pandas 사용하기
import pandas as pd

# %% [markdown]
# 판다스 공식문서 및 참고 링크
# - https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
# - https://dandyrilla.github.io/2017-08-12/pandas-10min/
# - https://doorbw.tistory.com/172

# %% [markdown]
# <br><br><br>
#
# ----------------------------------------

# %% [markdown]
# ## 1. 데이터 불러오기
#     1) 절대 경로를 통해 파일 열기
#     2) 상대 경로를 통해 파일 열기
# <br>
#
# **파일 위치 찾기**
#
# - 절대 경로: 파일이 가지고 있는 고유한 경로
# - 상대 경로: 현재 위치한 곳을 기준으로 한 경로
#
#
# **해당 파일 열기**
# - csv 파일 열기: .read_csv('파일명.csv')
# - excel 파일 열기: .read_excel('파일명.xlsx')
#
# <br><br>

# %% [markdown]
# ### 1) 절대 경로를 통해 파일 열기

# %%
pwd # 내 위치 확인
# Out:
# 'C:\\Users\\park\\Desktop\\datarian-kr\\01. Python Textbook'

# %%
# .read_csv('파일명.csv') csv 데이터 읽기
data=pd.read_csv('C:\\Users\\park\\Desktop\\datarian-kr\\01. Python Textbook/kr_googlestore.csv')

# %% [markdown]
# <br>
#
# ### 2) 상대 경로를 통해 파일 열기

# %%
# .read_csv('파일명.csv') csv 데이터 읽기
data=pd.read_csv('kr_googlestore.csv')

# %% [markdown]
# ----------
# <br><br><br><br><br>
#
# ## 02. 데이터 분석 맛보기

# %% [markdown]
# <br><br>
#
# ### 1) 데이터 샘플 뽑아 보기
#
# - .head(n)   : 상위 n개 데이터
# - .tail(n)   : 하위 n개 데이터
# - .sample(n) : 데이터 랜덤 샘플 n개
#
# <br><br>

# %% [markdown]
# #### 상위 n개 데이터 뽑기 : .head(n)  => (default : 5개)

# %%
data.head()
# Out:
#                                                   어플  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                Coloring book moana
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                              Sketch - Draw & Paint
# 4              Pixel Draw - Number Art Coloring Book
#
#                           장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 0               Art & Design  4.1     159  190.0     10000  무료  0  전체가
# 1  Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2               Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3               Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4    Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
#
#    안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 0       4.0     2018       1  2018.01
# 1       4.0     2018       1  2018.01
# 2       4.0     2018       8  2018.08
# 3       4.2     2018       6  2018.06
# 4       4.4     2018       6  2018.06

# %% [markdown]
# #### 하위 n개 데이터 뽑기 : .tail(n) => default : 5개

# %%
data.tail()
# Out:
#                                                    어플               장르   등급  \
# 95  All of the parking lot - National Park applica...  Auto & Vehicles  4.0
# 96               Inquiry Fines and Debits of Vehicles  Auto & Vehicles  NaN
# 97                                        Gas Station  Auto & Vehicles  4.0
# 98                              Hush - Beauty for 전체가           Beauty  4.7
# 99                     ipsy: Makeup, Beauty, and Tips           Beauty  NaN
#
#      리뷰 수     크기     설치 수  타입 가격  연령층  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 95   1754  140.0   500000  무료  0  전체가       4.0     2018       6  2018.06
# 96   2680    2.2   500000  무료  0  전체가       4.0     2018       3  2018.03
# 97   1288    4.5   100000  무료  0  전체가       4.0     2018       4  2018.04
# 98  18900  170.0   500000  무료  0  전체가       5.0     2018       8  2018.08
# 99  49790  140.0  1000000  무료  0  전체가       4.1     2017      11  2017.11

# %% [markdown]
# #### 데이터 랜덤 샘플 n개 뽑기 : .sample(n) => default : 10개

# %%
data.sample(10)
# Out:
#                                                    어플               장르   등급  \
# 54     Offroad Oil Tanker Driver Transport Truck 2019  Auto & Vehicles  NaN
# 95  All of the parking lot - National Park applica...  Auto & Vehicles  4.0
# 44        Popsicle Sticks and Similar DIY Craft Ideas     Art & Design  4.2
# 90                                           SMS Park  Auto & Vehicles  4.5
# 92                            Fuelio: Gas log & costs  Auto & Vehicles  NaN
# 20                        Logo Maker - Small Business     Art & Design  4.0
# 7                                    Infinite Painter     Art & Design  4.1
# 49                        Monster Truck Stunt 3D 2019  Auto & Vehicles  4.2
# 86                                    BEST CAR SOUNDS  Auto & Vehicles  4.3
# 88        AutoScout24 Switzerland – Find your new car  Auto & Vehicles  4.6
#
#      리뷰 수     크기     설치 수  타입     가격  연령층  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 54    542  330.0   100000  무료      0  전체가       4.1     2018       7  2018.07
# 95   1754  140.0   500000  무료      0  전체가       4.0     2018       6  2018.06
# 44     26  120.0    10000  무료      0  전체가       4.1     2018       1  2018.01
# 90   3617    7.9   100000  무료      0  전체가       4.1     2018       5  2018.05
# 92  65786    NaN  1000000  무료      0  전체가       4.0     2018       8  2018.08
# 20    450  140.0   100000  무료      0  전체가       4.1     2018       4  2018.04
# 7   36815  290.0  1000000  유료  $4.99  전체가       4.2     2018       6  2018.06
# 49    367  250.0   100000  무료      0  전체가       4.0     2018       5  2018.05
# 86    348  380.0   100000  무료      0  전체가       2.3     2018       7  2018.07
# 88  13372    NaN  1000000  무료      0  전체가       4.0     2018       8  2018.08

# %% [markdown]
# ---
# <br><br>
#
# ### 2) 데이터 행렬 조작하기
#
# - ```.index``` : Data Frame 속성/행 방향의 index
# - ```.columns``` : Data Frame 컬럼 / 열 방향의 index
# - ```.values``` : numpy 데이터 확인하기 => 값 얻기

# %% [markdown]
# <br><br>

# %% [markdown]
# #### 데이터 프레임 속성 확인 : .index

# %%
data.index
# Out:
# RangeIndex(start=0, stop=100, step=1)

# %% [markdown]
# #### 데이터 컬럼 확인 : .columns

# %%
data.columns
# Out:
# Index(['어플', '장르', '등급', '리뷰 수', '크기', '설치 수', '타입', '가격', '연령층', '안드로이드 버전',
#        '업데이트_년도', '업데이트_달', '업데이트_년달'],
#       dtype='object')

# %% [markdown]
# #### 데이터 확인 : .values

# %%
data.values
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook', 'Art & Design',
#         4.1, ..., 2018, 1, 2018.01],
#        ['Coloring book moana', 'Art & Design;Pretend Play', 3.9, ...,
#         2018, 1, 2018.01],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'Art & Design', 4.7, ..., 2018, 8, 2018.08],
#        ...,
#        ['Gas Station', 'Auto & Vehicles', 4.0, ..., 2018, 4, 2018.04],
#        ['Hush - Beauty for 전체가', 'Beauty', 4.7, ..., 2018, 8, 2018.08],
#        ['ipsy: Makeup, Beauty, and Tips', 'Beauty', nan, ..., 2017, 11,
#         2017.11]], dtype=object)

# %% [markdown]
# <br><br>
#
# ------

# %% [markdown]
# ### 3) 데이터를 자세하게 살펴보기 : uniqe, value

# %% [markdown]
# - ```unique``` : 데이터 안에 있는 값을 중복 없이 반환
# - ```nunique``` : 데이터 안에 있는 값을 중복 제외된 갯수를 확인
#
# <br>
#
# - ```values```: 데이터 안에 어떤 값이 들어있는지 중복 포함하여 모두 반환
# - ```value_counts```: 데이터 안에 어떤 값이 들어있는지 갯수 확인

# %% [markdown]
# <br><br>

# %% [markdown]
# #### 데이터 값의 종류 확인 : unique()

# %%
data['안드로이드 버전'].unique()
# Out:
# array([4. , 4.2, 4.4, 2.3, 3. , 4.1, 2.2, 5. , 6. ])

# %% [markdown]
# #### 데이터 값의 종류 갯수 확인 : nuniqe()

# %%
data['안드로이드 버전'].nunique()
# Out:
# 9

# %% [markdown]
# #### 데이터 값 확인 : values

# %%
data['안드로이드 버전'].values
# Out:
# array([4. , 4. , 4. , 4.2, 4.4, 2.3, 4. , 4.2, 3. , 4. , 4.1, 4. , 4.1,
#        4.4, 2.3, 4.2, 4.1, 2.3, 4. , 4.1, 4.1, 4. , 4. , 4.1, 4.1, 3. ,
#        4. , 4. , 2.3, 2.3, 4. , 2.3, 4. , 4.1, 4.1, 4.1, 4.4, 2.3, 4. ,
#        4. , 4. , 4. , 4. , 4.1, 4.1, 4.1, 4.1, 4.1, 2.3, 4. , 4.1, 4.1,
#        4.1, 4.1, 4.1, 4. , 4.4, 4.1, 2.2, 4.4, 4. , 4.2, 4.1, 4. , 4.2,
#        4.4, 2.3, 2.3, 2.3, 4. , 4. , 4.2, 5. , 2.3, 4. , 4. , 4.1, 4. ,
#        4.1, 4.1, 6. , 4.2, 5. , 4. , 4.4, 4.4, 2.3, 4. , 4. , 4. , 4.1,
#        4. , 4. , 4. , 4. , 4. , 4. , 4. , 5. , 4.1])

# %% [markdown]
# #### 데이터 값의 종류 갯수 확인 : value_counts()

# %%
data['안드로이드 버전'].value_counts()
# Out:
# 4.0    38
# 4.1    27
# 2.3    13
# 4.4     8
# 4.2     7
# 5.0     3
# 3.0     2
# 2.2     1
# 6.0     1
# Name: 안드로이드 버전, dtype: int64

# %% [markdown]
# ---
# <br><br><br><br><br>

# %% [markdown]
# ### 결측치(missing)
#
# missing 값 채우는 방법
# - missing 값 채우기
# - isnull() 메소드는 관측치가 결측이면, True / 결측이 아니면, False의 boollean 값 반환
# - notnull()메소드는 관측치가 결측이면, False / 결측이 아니면, True의 boollean 값 반환 -> isnull 정반대.

# %%
pd.isnull(data)
# Out:
#        어플     장르     등급   리뷰 수     크기   설치 수     타입     가격    연령층  안드로이드 버전  \
# 0   False  False  False  False  False  False  False  False  False     False
# 1   False  False  False  False  False  False  False  False  False     False
# 2   False  False  False  False  False  False  False  False  False     False
# 3   False  False  False  False  False  False  False  False  False     False
# 4   False  False  False  False  False  False  False  False  False     False
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...       ...
# 95  False  False  False  False  False  False  False  False  False     False
# 96  False  False   True  False  False  False  False  False  False     False
# 97  False  False  False  False  False  False  False  False  False     False
# 98  False  False  False  False  False  False  False  False  False     False
# 99  False  False   True  False  False  False  False  False  False     False
#
#     업데이트_년도  업데이트_달  업데이트_년달
# 0     False   False    False
# 1     False   False    False
# 2     False   False    False
# 3     False   False    False
# 4     False   False    False
# ..      ...     ...      ...
# 95    False   False    False
# 96    False   False    False
# 97    False   False    False
# 98    False   False    False
# 99    False   False    False
#
# [100 rows x 13 columns]

# %% [markdown]
# 칼럼별 결측값 개수 구하기: df.isnull().sum()

# %%
data.isnull().sum()
# Out:
# 어플           0
# 장르           0
# 등급          17
# 리뷰 수         0
# 크기          10
# 설치 수         0
# 타입           0
# 가격           0
# 연령층          0
# 안드로이드 버전     0
# 업데이트_년도      0
# 업데이트_달       0
# 업데이트_년달      0
# dtype: int64

# %%
data['크기'].isnull().sum()
# Out:
# 10

# %% [markdown]
# **결측치 연산 방법**
# - 참고: https://rfriend.tistory.com/261?category=675917

# %% [markdown]
# 1) sum(), cumsum() methods 계산 시 : NaN은 '0'으로 처리

# %% [markdown]
# 2) mean(), std() 연산 시 : NaN은 분석 대상(population)에서 제외

# %% [markdown]
# 3) DataFrame 칼럼 간 연산 시 : NaN이 하나라도 있으면 NaN 반환
# 4) 컬럼을 아예 삭제하거나 등등등등

# %%
# Nan 제외하고 평균 만들어짐.
data['등급'].mean()
# Out:
# 4.289156626506025

# %%
# Nan 제외하고 std 만들어짐.
data['등급'].std()
# Out:
# 0.3675933756246364

# %%
data['크기'].mean()
# Out:
# 146.26777777777775

# %%
# 데이터 null 값 넣기. 
data.loc[data['등급'].isnull(), '등급'] = 4.2
data.loc[data['크기'].isnull(), '크기'] = 144.2
# data=data.fillna(data.mean())

# %%
data.isnull().sum()
# Out:
# 어플          0
# 장르          0
# 등급          0
# 리뷰 수        0
# 크기          0
# 설치 수        0
# 타입          0
# 가격          0
# 연령층         0
# 안드로이드 버전    0
# 업데이트_년도     0
# 업데이트_달      0
# 업데이트_년달     0
# dtype: int64

# %%
# 조건을 충족할 때, 결측치를 넣어주세요. 
'''
check_null = data['등급'].isnull()
condition1 = data['리뷰수'] >= 100

data.loc[check_null & condition1, '등급'] = 4.2 '''
# Out:
# "\ncheck_null = data['등급'].isnull()\ncondition1 = data['리뷰수'] >= 100\n\ndata.loc[check_null & condition1, '등급'] = 4.2 "

# %% [markdown]
# **타입에 일부러 nan만들어서, 조건 충족 하면 어떨까요?**

# %%
# data.loc[data['등급'].isnull(), '등급'] = 4.2

# %%
# .T 속성 -> Transpose index and columns. => index와 column 바꾼 형태.
# data.T

# %%
# 각 인덱스에 대한 이름 설정하기
data.index.name = '순서'
data.columns.name = '컬럼'
data
# Out:
# 컬럼                                                 어플  \
# 순서
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                 Coloring book moana
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                               Sketch - Draw & Paint
# 4               Pixel Draw - Number Art Coloring Book
# ..                                                ...
# 95  All of the parking lot - National Park applica...
# 96               Inquiry Fines and Debits of Vehicles
# 97                                        Gas Station
# 98                              Hush - Beauty for 전체가
# 99                     ipsy: Makeup, Beauty, and Tips
#
# 컬럼                         장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 순서
# 0                Art & Design  4.1     159  190.0     10000  무료  0  전체가
# 1   Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2                Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3                Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4     Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
# ..                        ...  ...     ...    ...       ...  .. ..  ...
# 95            Auto & Vehicles  4.0    1754  140.0    500000  무료  0  전체가
# 96            Auto & Vehicles  4.2    2680    2.2    500000  무료  0  전체가
# 97            Auto & Vehicles  4.0    1288    4.5    100000  무료  0  전체가
# 98                     Beauty  4.7   18900  170.0    500000  무료  0  전체가
# 99                     Beauty  4.2   49790  140.0   1000000  무료  0  전체가
#
# 컬럼  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 순서
# 0        4.0     2018       1  2018.01
# 1        4.0     2018       1  2018.01
# 2        4.0     2018       8  2018.08
# 3        4.2     2018       6  2018.06
# 4        4.4     2018       6  2018.06
# ..       ...      ...     ...      ...
# 95       4.0     2018       6  2018.06
# 96       4.0     2018       3  2018.03
# 97       4.0     2018       4  2018.04
# 98       5.0     2018       8  2018.08
# 99       4.1     2017      11  2017.11
#
# [100 rows x 13 columns]

# %% [markdown]
# ---
# <br><br><br><br><br>

# %% [markdown]
# **통계 함수**
# - mead() 평균
# - std() 표준편차
# - sum() 합계
# - median() 중위수
# - min() 최솟값
# - max() 최댓값
# - n() 빈도

# %%
# describe() 함수 -> data frame의 간단한 통계 정보를 알려준다. 
data.describe()
# Out:
# 컬럼             등급           리뷰 수          크기          설치 수    안드로이드 버전  \
# count  100.000000     100.000000  100.000000  1.000000e+02  100.000000
# mean     4.274000   24486.050000  146.061000  1.583150e+06    3.864000
# std      0.336236   59275.316059  140.190275  5.431636e+06    0.709178
# min      3.200000      26.000000    1.100000  5.000000e+03    2.200000
# 25%      4.100000     275.500000    6.075000  1.000000e+05    4.000000
# 50%      4.200000    1460.500000  144.200000  1.000000e+05    4.000000
# 75%      4.600000   13476.750000  232.500000  1.000000e+06    4.100000
# max      4.900000  295221.000000  570.000000  5.000000e+07    6.000000
#
# 컬럼         업데이트_년도      업데이트_달      업데이트_년달
# count   100.000000  100.000000   100.000000
# mean   2017.840000    6.450000  2017.904500
# std       0.526471    2.185235     0.518265
# min    2014.000000    1.000000  2014.080000
# 25%    2018.000000    5.000000  2018.040000
# 50%    2018.000000    7.000000  2018.070000
# 75%    2018.000000    7.000000  2018.070000
# max    2018.000000   12.000000  2018.080000

# %%
# 최댓갓 예시
data['크기'].max()
# Out:
# 570.0

# %%
# DataFrame을 만들면서 columns와 index를 설정할 수 있다.
df2 = pd.DataFrame(data, columns=['year', 'name', 'points', 'penalty'],
                  index=['one', 'two', 'three', 'four', 'five'])
df2
# Out:
#        year  name  points  penalty
# one     NaN   NaN     NaN      NaN
# two     NaN   NaN     NaN      NaN
# three   NaN   NaN     NaN      NaN
# four    NaN   NaN     NaN      NaN
# five    NaN   NaN     NaN      NaN

# %%
# DataFrame을 만들면서 columns와 index를 설정할 수 있다.
data2 = pd.DataFrame(data, columns=['year', 'name', 'points', 'penalty'],
                  index=['one', 'two', 'three', 'four', 'five'])
df2
# Out:
#        year  name  points  penalty
# one     NaN   NaN     NaN      NaN
# two     NaN   NaN     NaN      NaN
# three   NaN   NaN     NaN      NaN
# four    NaN   NaN     NaN      NaN
# five    NaN   NaN     NaN      NaN

# %% [markdown]
# ---
# <br><br><br><br><br>

# %% [markdown]
# **정렬 .sort_inex()** -> 행과 열 이름 정렬
#
# 정렬할 대상 축을 결정할 때, axis.
# - axis = 0 => 인덱스 기준 정렬(기본값)
# - axis = 1 => 컬럼 기준.
#
# 정렬의 방향에 대한 파라미터, ascending.
# - ascending = True 오름차순(기본값)
# - ascending = False 내림차순

# %%
# 내림차순 정렬 예시
data.sort_index(axis=1, ascending=False)
# Out:
# 컬럼  타입     크기                         장르  연령층  업데이트_달  업데이트_년도  업데이트_년달  \
# 순서
# 0   무료  190.0               Art & Design  전체가       1     2018  2018.01
# 1   무료  140.0  Art & Design;Pretend Play  전체가       1     2018  2018.01
# 2   무료    8.7               Art & Design  전체가       8     2018  2018.08
# 3   무료  250.0               Art & Design  청소년       6     2018  2018.06
# 4   무료    2.8    Art & Design;Creativity  전체가       6     2018  2018.06
# ..  ..    ...                        ...  ...     ...      ...      ...
# 95  무료  140.0            Auto & Vehicles  전체가       6     2018  2018.06
# 96  무료    2.2            Auto & Vehicles  전체가       3     2018  2018.03
# 97  무료    4.5            Auto & Vehicles  전체가       4     2018  2018.04
# 98  무료  170.0                     Beauty  전체가       8     2018  2018.08
# 99  무료  140.0                     Beauty  전체가      11     2017  2017.11
#
# 컬럼                                                 어플  안드로이드 버전      설치 수  \
# 순서
# 0      Photo Editor & Candy Camera & Grid & ScrapBook       4.0     10000
# 1                                 Coloring book moana       4.0    500000
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...       4.0   5000000
# 3                               Sketch - Draw & Paint       4.2  50000000
# 4               Pixel Draw - Number Art Coloring Book       4.4    100000
# ..                                                ...       ...       ...
# 95  All of the parking lot - National Park applica...       4.0    500000
# 96               Inquiry Fines and Debits of Vehicles       4.0    500000
# 97                                        Gas Station       4.0    100000
# 98                              Hush - Beauty for 전체가       5.0    500000
# 99                     ipsy: Makeup, Beauty, and Tips       4.1   1000000
#
# 컬럼    리뷰 수   등급 가격
# 순서
# 0      159  4.1  0
# 1      967  3.9  0
# 2    87510  4.7  0
# 3   215644  4.5  0
# 4      967  4.3  0
# ..     ...  ... ..
# 95    1754  4.0  0
# 96    2680  4.2  0
# 97    1288  4.0  0
# 98   18900  4.7  0
# 99   49790  4.2  0
#
# [100 rows x 13 columns]

# %%
# DataFrame 내부 값 정렬. -> 정렬 기준
data.sort_values(by='등급')
# Out:
# 컬럼                                                 어플  \
# 순서
# 15                    Learn To Draw Kawaii Characters
# 87                      RST - Sale of cars on the PCT
# 91                                            SKencar
# 84        Used car search Goo net whole car Go to net
# 43                                      Paint Splash!
# ..                                                ...
# 70  Fines of the State Traffic Safety Inspectorate...
# 25                         Harley Quinn wallpapers HD
# 64              DMV Permit Practice Test 2018 Edition
# 61                     CDL Practice Test 2018 Edition
# 79                            Tickets + PDA 2018 Exam
#
# 컬럼                       장르   등급    리뷰 수     크기     설치 수  타입      가격  연령층  \
# 순서
# 15             Art & Design  3.2      55    2.7     5000  무료       0  전체가
# 87          Auto & Vehicles  3.2     250    1.1   100000  무료       0  전체가
# 91          Auto & Vehicles  3.7    4806  350.0  1000000  무료       0  전체가
# 84          Auto & Vehicles  3.7    5414  180.0  1000000  무료       0  전체가
# 43  Art & Design;Creativity  3.8    2206    1.2   100000  유료  $15.46  전체가
# ..                      ...  ...     ...    ...      ...  ..     ...  ...
# 70          Auto & Vehicles  4.8  116986  350.0  5000000  유료   $4.99  전체가
# 25             Art & Design  4.8     192    6.0    10000  무료       0  전체가
# 64          Auto & Vehicles  4.9    6090  270.0   100000  유료  $15.46  전체가
# 61          Auto & Vehicles  4.9    7774  170.0   100000  유료   $9.75  전체가
# 79          Auto & Vehicles  4.9  197136  380.0  1000000  무료       0  전체가
#
# 컬럼  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 순서
# 15       4.2     2018       6  2018.06
# 87       4.0     2018       4  2018.04
# 91       4.0     2018       7  2018.07
# 84       4.4     2018       7  2018.07
# 43       4.1     2018       4  2018.04
# ..       ...      ...     ...      ...
# 70       4.0     2018       8  2018.08
# 25       3.0     2018       4  2018.04
# 64       4.2     2018       7  2018.07
# 61       4.2     2018       7  2018.07
# 79       4.1     2018       7  2018.07
#
# [100 rows x 13 columns]

# %% [markdown]
# ---
# <br><br><br><br><br>

# %% [markdown]
# **데이터 선택**

# %%
# 데이터 선택 -> 특정 '컬럼'의 값 가져오기
data['어플']
# Out:
# 순서
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                   Coloring book moana
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                 Sketch - Draw & Paint
# 4                 Pixel Draw - Number Art Coloring Book
#                             ...
# 95    All of the parking lot - National Park applica...
# 96                 Inquiry Fines and Debits of Vehicles
# 97                                          Gas Station
# 98                                Hush - Beauty for 전체가
# 99                       ipsy: Makeup, Beauty, and Tips
# Name: 어플, Length: 100, dtype: object

# %%
# 이하 동일. -> app 컬럼 값들만 가져옴.
data.어플
# Out:
# 순서
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                   Coloring book moana
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                 Sketch - Draw & Paint
# 4                 Pixel Draw - Number Art Coloring Book
#                             ...
# 95    All of the parking lot - National Park applica...
# 96                 Inquiry Fines and Debits of Vehicles
# 97                                          Gas Station
# 98                                Hush - Beauty for 전체가
# 99                       ipsy: Makeup, Beauty, and Tips
# Name: 어플, Length: 100, dtype: object

# %%
# 맨 처음 5개의 행을 가져온다
data[0:5]
# Out:
# 컬럼                                                 어플  \
# 순서
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                 Coloring book moana
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                               Sketch - Draw & Paint
# 4               Pixel Draw - Number Art Coloring Book
#
# 컬럼                         장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 순서
# 0                Art & Design  4.1     159  190.0     10000  무료  0  전체가
# 1   Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2                Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3                Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4     Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
#
# 컬럼  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 순서
# 0        4.0     2018       1  2018.01
# 1        4.0     2018       1  2018.01
# 2        4.0     2018       8  2018.08
# 3        4.2     2018       6  2018.06
# 4        4.4     2018       6  2018.06

# %%
# index가 [12:15]에 해당하는 것만 가져온다.
data[12:15]
# Out:
# 컬럼                                               어플            장르   등급   리뷰 수  \
# 순서
# 12                   Tattoo Name On My Photo Editor  Art & Design  4.2  44829
# 13                            Mandala Coloring Book  Art & Design  4.6   4326
# 14  3D Color Pixel by Number - Sandbox Art Coloring  Art & Design  4.2   1518
#
# 컬럼     크기      설치 수  타입     가격  연령층  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 순서
# 12  200.0  10000000  무료      0  청소년       4.1     2018       4  2018.04
# 13  210.0    100000  무료      0  전체가       4.4     2018       6  2018.06
# 14  370.0    100000  유료  $1.99  전체가       2.3     2018       8  2018.08

# %%
# 이름 이용 선택: loc -> 왜 안되는 것인가.
data.loc[등급[4]]
#data.loc[App['Tattoo Name On My Photo Editor']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-af5e77c25bc7> in <module>
#       1 # 이름 이용 선택: loc -> 왜 안되는 것인가.
# ----> 2 data.loc[등급[4]]
#       3 #data.loc[App['Tattoo Name On My Photo Editor']]
#
# NameError: name '등급' is not defined

# %%
# 컬럼 App, Rating에 대한 모든 값 가져오기
data.loc[:,['어플', '등급']]
# Out:
# 컬럼                                                 어플   등급
# 순서
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  4.1
# 1                                 Coloring book moana  3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  4.7
# 3                               Sketch - Draw & Paint  4.5
# 4               Pixel Draw - Number Art Coloring Book  4.3
# ..                                                ...  ...
# 95  All of the parking lot - National Park applica...  4.0
# 96               Inquiry Fines and Debits of Vehicles  4.2
# 97                                        Gas Station  4.0
# 98                              Hush - Beauty for 전체가  4.7
# 99                     ipsy: Makeup, Beauty, and Tips  4.2
#
# [100 rows x 2 columns]

# %%
data.head()
# Out:
# 컬럼                                                 어플  \
# 순서
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                 Coloring book moana
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                               Sketch - Draw & Paint
# 4               Pixel Draw - Number Art Coloring Book
#
# 컬럼                         장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 순서
# 0                Art & Design  4.1     159  190.0     10000  무료  0  전체가
# 1   Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2                Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3                Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4     Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
#
# 컬럼  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 순서
# 0        4.0     2018       1  2018.01
# 1        4.0     2018       1  2018.01
# 2        4.0     2018       8  2018.08
# 3        4.2     2018       6  2018.06
# 4        4.4     2018       6  2018.06

# %%
# 특정 인덱스 값의 컬럼 App, Rating에 대한 모든 값 가져오기
data.loc[순서[5], ['어플', '등급']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-b8028ba47970> in <module>
#       1 # 특정 인덱스 값의 컬럼 App, Rating에 대한 모든 값 가져오기
# ----> 2 data.loc[순서[5], ['어플', '등급']]
#
# NameError: name '순서' is not defined

# %%
# 특정 인덱스 값과 특정 컬럼에 있는 값 가져오기 -> .at 이용  가능
data.loc[[5],'어플']
data.at[업데이트_년도[5], '어플']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-1e2352bee685> in <module>
#       1 # 특정 인덱스 값과 특정 컬럼에 있는 값 가져오기 -> .at 이용  가능
#       2 data.loc[[5],'어플']
# ----> 3 data.at[업데이트_년도[5], '어플']
#
# NameError: name '업데이트_년도' is not defined

# %% [markdown]
# **위치 이용하여 선택하기**: .iloc

# %%
# python 인덱스 개념. 즉, 5번째 인덱스를 가져오는 게 아닌 6번째 인덱스 get 
data.iloc[5]
# Out:
# 컬럼
# 어플          Paper flowers instructions
# 장르                        Art & Design
# 등급                                 4.4
# 리뷰 수                               167
# 크기                                 5.6
# 설치 수                             50000
# 타입                                  무료
# 가격                                   0
# 연령층                                전체가
# 안드로이드 버전                           2.3
# 업데이트_년도                           2017
# 업데이트_달                               3
# 업데이트_년달                        2017.03
# Name: 5, dtype: object

# %%
# 데이터 슬라이싱 및 인덱스
data.iloc[3:5,0:2]
# Out:
# 컬럼                                     어플                       장르
# 순서
# 3                   Sketch - Draw & Paint             Art & Design
# 4   Pixel Draw - Number Art Coloring Book  Art & Design;Creativity

# %%
# 데이터 슬라이싱 및 인덱스
df.iloc[[1,2,4],[0,2]]
# Out:
#    name  scroe
# 1  park     68
# 2   lee     79
# 4   tae     87

# %%
# 명시적으로 행이나 열 선택 인자에 ' : ' 있으면 -> 행 or 열 전체 가져와라
data.iloc[1:5,:]
# data.iloc[:,1:5]
# Out:
# 컬럼                                                 어플  \
# 순서
# 1                                 Coloring book moana
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                               Sketch - Draw & Paint
# 4               Pixel Draw - Number Art Coloring Book
#
# 컬럼                         장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 순서
# 1   Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2                Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3                Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4     Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
#
# 컬럼  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 순서
# 1        4.0     2018       1  2018.01
# 2        4.0     2018       8  2018.08
# 3        4.2     2018       6  2018.06
# 4        4.4     2018       6  2018.06

# %%
# 값 하나를 섲ㄴ택하기 위해 특정 행과 열 지정 방식. 
data.iloc[4,2]
#data.iat[4,2]
# Out:
# 4.3

# %% [markdown]
# **조건 이용 선택**

# %%
# Rating > 3.7 이상 인 데이터만 뽑음
data[data.등급 > 3.7]
# Out:
# 컬럼                                                 어플  \
# 순서
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                 Coloring book moana
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                               Sketch - Draw & Paint
# 4               Pixel Draw - Number Art Coloring Book
# ..                                                ...
# 95  All of the parking lot - National Park applica...
# 96               Inquiry Fines and Debits of Vehicles
# 97                                        Gas Station
# 98                              Hush - Beauty for 전체가
# 99                     ipsy: Makeup, Beauty, and Tips
#
# 컬럼                         장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 순서
# 0                Art & Design  4.1     159  190.0     10000  무료  0  전체가
# 1   Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2                Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3                Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4     Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
# ..                        ...  ...     ...    ...       ...  .. ..  ...
# 95            Auto & Vehicles  4.0    1754  140.0    500000  무료  0  전체가
# 96            Auto & Vehicles  4.2    2680    2.2    500000  무료  0  전체가
# 97            Auto & Vehicles  4.0    1288    4.5    100000  무료  0  전체가
# 98                     Beauty  4.7   18900  170.0    500000  무료  0  전체가
# 99                     Beauty  4.2   49790  140.0   1000000  무료  0  전체가
#
# 컬럼  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 순서
# 0        4.0     2018       1  2018.01
# 1        4.0     2018       1  2018.01
# 2        4.0     2018       8  2018.08
# 3        4.2     2018       6  2018.06
# 4        4.4     2018       6  2018.06
# ..       ...      ...     ...      ...
# 95       4.0     2018       6  2018.06
# 96       4.0     2018       3  2018.03
# 97       4.0     2018       4  2018.04
# 98       5.0     2018       8  2018.08
# 99       4.1     2017      11  2017.11
#
# [96 rows x 13 columns]

# %% [markdown]
# ---
# <br><br><br><br><br>

# %% [markdown]
# **데이터 변경하기**
#
# 데이터 프레임 특정 값들을 다른 값으로 변경 할 수 있다.
#
# 기존 데이터 프레임에 새로운 열을 추가하고 싶을 때는 다음과 같이 같은 인덱스를 가진 시리즈 하나를 데이터 프레임 열 하나를 지정하여 넣어준다

# %%
# 값 알맞게 찾아서 넣기. 
test = pd.Series(['Photo Editor', 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))

# %% [markdown]
# 여기서 부터 약간 꼬임-> 사실 그 전부터 꼬임.

# %%
test
# Out:
# 2013-01-02    Photo Editor
# 2013-01-03               2
# 2013-01-04               3
# 2013-01-05               4
# 2013-01-06               5
# 2013-01-07               6
# Freq: D, dtype: object

# %%
# data['F'] = test

# %%
data
# Out:
# 컬럼                                                 어플  \
# 순서
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                 Coloring book moana
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                               Sketch - Draw & Paint
# 4               Pixel Draw - Number Art Coloring Book
# ..                                                ...
# 95  All of the parking lot - National Park applica...
# 96               Inquiry Fines and Debits of Vehicles
# 97                                        Gas Station
# 98                              Hush - Beauty for 전체가
# 99                     ipsy: Makeup, Beauty, and Tips
#
# 컬럼                         장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 순서
# 0                Art & Design  4.1     159  190.0     10000  무료  0  전체가
# 1   Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2                Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3                Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4     Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
# ..                        ...  ...     ...    ...       ...  .. ..  ...
# 95            Auto & Vehicles  4.0    1754  140.0    500000  무료  0  전체가
# 96            Auto & Vehicles  4.2    2680    2.2    500000  무료  0  전체가
# 97            Auto & Vehicles  4.0    1288    4.5    100000  무료  0  전체가
# 98                     Beauty  4.7   18900  170.0    500000  무료  0  전체가
# 99                     Beauty  4.2   49790  140.0   1000000  무료  0  전체가
#
# 컬럼  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 순서
# 0        4.0     2018       1  2018.01
# 1        4.0     2018       1  2018.01
# 2        4.0     2018       8  2018.08
# 3        4.2     2018       6  2018.06
# 4        4.4     2018       6  2018.06
# ..       ...      ...     ...      ...
# 95       4.0     2018       6  2018.06
# 96       4.0     2018       3  2018.03
# 97       4.0     2018       4  2018.04
# 98       5.0     2018       8  2018.08
# 99       4.1     2017      11  2017.11
#
# [100 rows x 13 columns]

# %%
# 데이터 프레임의 특정 값 하나를 선택하여 다른 값으로 변경. -> 넌 또 왜 안돼.
data.at[name[0], 'APP'] = 3.7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-8bc3d106b6a1> in <module>
#       1 # 데이터 프레임의 특정 값 하나를 선택하여 다른 값으로 변경. -> 넌 또 왜 안돼.
# ----> 2 data.at[name[0], 'APP'] = 3.7
#
# NameError: name 'name' is not defined

# %%
# 값의 위치(인덱스 번호)를 이용한 변경 가능
data.iat[0,4] = 3.7

# %%
# 데이터 내용 한꺼번에 바꾸기 -> 어떻게 변경 되었는가
data.loc[:,'어플'] = np.array([5] * len(data))

# %%
data
# Out:
# 컬럼  어플                         장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 순서
# 0    5               Art & Design  4.1     159    3.7     10000  무료  0  전체가
# 1    5  Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2    5               Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3    5               Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4    5    Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
# ..  ..                        ...  ...     ...    ...       ...  .. ..  ...
# 95   5            Auto & Vehicles  4.0    1754  140.0    500000  무료  0  전체가
# 96   5            Auto & Vehicles  NaN    2680    2.2    500000  무료  0  전체가
# 97   5            Auto & Vehicles  4.0    1288    4.5    100000  무료  0  전체가
# 98   5                     Beauty  4.7   18900  170.0    500000  무료  0  전체가
# 99   5                     Beauty  NaN   49790  140.0   1000000  무료  0  전체가
#
# 컬럼  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달    F  App
# 순서
# 0        4.0     2018       1  2018.01  NaN    5
# 1        4.0     2018       1  2018.01  NaN    5
# 2        4.0     2018       8  2018.08  NaN    5
# 3        4.2     2018       6  2018.06  NaN    5
# 4        4.4     2018       6  2018.06  NaN    5
# ..       ...      ...     ...      ...  ...  ...
# 95       4.0     2018       6  2018.06  NaN    5
# 96       4.0     2018       3  2018.03  NaN    5
# 97       4.0     2018       4  2018.04  NaN    5
# 98       5.0     2018       8  2018.08  NaN    5
# 99       4.1     2017      11  2017.11  NaN    5
#
# [100 rows x 15 columns]

# %%
# 지정한 행 또는 열에서 중복값을 제외한 유니크한 값만 얻기
data['크기'].unique()
# Out:
# array([  3.7, 140. ,   8.7, 250. ,   2.8,   5.6, 190. , 290. , 330. ,
#          3.1, 280. , 120. , 200. , 210. , 370. ,   2.7,   5.5, 170. ,
#        390. , 310. ,   4.2,   7. , 230. ,   6. ,   6.1,   4.6,   9.2,
#          5.2, 110. , 240. ,   nan,   9.4, 150. , 100. ,   1.2, 260. ,
#          8. ,   7.9, 560. , 570. , 350. , 540. , 201. ,   3.6,   5.7,
#          8.6,   2.4, 270. ,   2.5, 160. ,   3.4,   8.9,   3.9,   2.9,
#        380. , 320. ,   5.4, 180. ,   1.1,   2.2,   4.5])

# %%
# 지정한 행 또는 열에서 값에 따른 개수 얻기
data['크기'].value_counts()
# Out:
# 170.0    5
# 140.0    4
# 330.0    3
# 4.2      3
# 350.0    3
# 120.0    3
# 110.0    3
# 250.0    3
# 5.6      2
# 190.0    2
# 240.0    2
# 380.0    2
# 370.0    2
# 9.2      2
# 7.0      2
# 2.7      2
# 150.0    2
# 7.9      2
# 160.0    2
# 560.0    1
# 8.0      1
# 260.0    1
# 100.0    1
# 390.0    1
# 6.0      1
# 230.0    1
# 310.0    1
# 5.5      1
# 210.0    1
# 200.0    1
# 280.0    1
# 290.0    1
# 570.0    1
# 8.9      1
# 540.0    1
# 201.0    1
# 5.7      1
# 4.6      1
# 3.6      1
# 6.1      1
# 1.1      1
# 2.8      1
# 3.7      1
# 8.7      1
# 9.4      1
# 5.2      1
# 2.9      1
# 5.4      1
# 3.9      1
# 3.4      1
# 2.4      1
# 8.6      1
# 3.1      1
# 1.2      1
# 4.5      1
# 180.0    1
# 320.0    1
# 2.2      1
# 270.0    1
# 2.5      1
# Name: 크기, dtype: int64

# %% [markdown]
# **pandas에서 DataFrame에 적용되는 함수들**
#
# sum() 함수 이외에도 pandas에서 DataFrame에 적용되는 함수는 다음의 것들이 있다.
#
# count 전체 성분의 (NaN이 아닌) 값의 갯수를 계산
#
# min, max 전체 성분의 최솟, 최댓값을 계산
#
# argmin, argmax 전체 성분의 최솟값, 최댓값이 위치한 (정수)인덱스를 반환
#
# idxmin, idxmax 전체 인덱스 중 최솟값, 최댓값을 반환
#
# quantile 전체 성분의 특정 사분위수에 해당하는 값을 반환 (0~1 사이)
#
# sum 전체 성분의 합을 계산
#
# mean 전체 성분의 평균을 계산
#
# median 전체 성분의 중간값을 반환
#
# mad 전체 성분의 평균값으로부터의 절대 편차(absolute deviation)의 평균을 계산
#
# std, var 전체 성분의 표준편차, 분산을 계산
#
# cumsum 맨 첫 번째 성분부터 각 성분까지의 누적합을 계산 (0에서부터 계속 더해짐)
#
# cumprod 맨 첫번째 성분부터 각 성분까지의 누적곱을 계산 (1에서부터 계속 곱해짐
#
#
#
# 출처: https://doorbw.tistory.com/172 [Tigercow.Door]

# %% [markdown]
# **통계적 지표**

# %%
# 평균 구하기. -> 일반적으로 결측치 제외하고 연산.
data.mean
# Out:
# <bound method DataFrame.mean of 컬럼                                                 어플  \
# 순서
# 0      Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                 Coloring book moana
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                               Sketch - Draw & Paint
# 4               Pixel Draw - Number Art Coloring Book
# ..                                                ...
# 95  All of the parking lot - National Park applica...
# 96               Inquiry Fines and Debits of Vehicles
# 97                                        Gas Station
# 98                              Hush - Beauty for 전체가
# 99                     ipsy: Makeup, Beauty, and Tips
#
# 컬럼                         장르   등급    리뷰 수     크기      설치 수  타입 가격  연령층  \
# 순서
# 0                Art & Design  4.1     159  190.0     10000  무료  0  전체가
# 1   Art & Design;Pretend Play  3.9     967  140.0    500000  무료  0  전체가
# 2                Art & Design  4.7   87510    8.7   5000000  무료  0  전체가
# 3                Art & Design  4.5  215644  250.0  50000000  무료  0  청소년
# 4     Art & Design;Creativity  4.3     967    2.8    100000  무료  0  전체가
# ..                        ...  ...     ...    ...       ...  .. ..  ...
# 95            Auto & Vehicles  4.0    1754  140.0    500000  무료  0  전체가
# 96            Auto & Vehicles  4.2    2680    2.2    500000  무료  0  전체가
# 97            Auto & Vehicles  4.0    1288    4.5    100000  무료  0  전체가
# 98                     Beauty  4.7   18900  170.0    500000  무료  0  전체가
# 99                     Beauty  4.2   49790  140.0   1000000  무료  0  전체가
#
# 컬럼  안드로이드 버전  업데이트_년도  업데이트_달  업데이트_년달
# 순서
# 0        4.0     2018       1  2018.01
# 1        4.0     2018       1  2018.01
# 2        4.0     2018       8  2018.08
# 3        4.2     2018       6  2018.06
# 4        4.4     2018       6  2018.06
# ..       ...      ...     ...      ...
# 95       4.0     2018       6  2018.06
# 96       4.0     2018       3  2018.03
# 97       4.0     2018       4  2018.04
# 98       5.0     2018       8  2018.08
# 99       4.1     2017      11  2017.11
#
# [100 rows x 13 columns]>

# %% [markdown]
# **함수 적용(Apply)**
# - 기존에 존재하는 함수를 사용하거나 사용자가 정의한 람다 함수를 사용할 수 있다.

# %%
#data.apply(np.cumsum)
# Out:
# 컬럼   어플                                                 장르     등급     리뷰 수  \
# 순서
# 0     5                                       Art & Design    4.1      159
# 1    10              Art & DesignArt & Design;Pretend Play    8.0     1126
# 2    15  Art & DesignArt & Design;Pretend PlayArt & Design   12.7    88636
# 3    20  Art & DesignArt & Design;Pretend PlayArt & Des...   17.2   304280
# 4    25  Art & DesignArt & Design;Pretend PlayArt & Des...   21.5   305247
# ..  ...                                                ...    ...      ...
# 95  480  Art & DesignArt & Design;Pretend PlayArt & Des...  347.3  2375947
# 96  485  Art & DesignArt & Design;Pretend PlayArt & Des...    NaN  2378627
# 97  490  Art & DesignArt & Design;Pretend PlayArt & Des...  351.3  2379915
# 98  495  Art & DesignArt & Design;Pretend PlayArt & Des...  356.0  2398815
# 99  500  Art & DesignArt & Design;Pretend PlayArt & Des...    NaN  2448605
#
# 컬럼       크기       설치 수                                                 타입  \
# 순서
# 0       3.7      10000                                                 무료
# 1     143.7     510000                                               무료무료
# 2     152.4    5510000                                             무료무료무료
# 3     402.4   55510000                                           무료무료무료무료
# 4     405.2   55610000                                         무료무료무료무료무료
# ..      ...        ...                                                ...
# 95  12661.1  156215000  무료무료무료무료무료무료무료유료무료무료무료무료무료무료유료무료무료무료무료무료무료무료무료...
# 96  12663.3  156715000  무료무료무료무료무료무료무료유료무료무료무료무료무료무료유료무료무료무료무료무료무료무료무료...
# 97  12667.8  156815000  무료무료무료무료무료무료무료유료무료무료무료무료무료무료유료무료무료무료무료무료무료무료무료...
# 98  12837.8  157315000  무료무료무료무료무료무료무료유료무료무료무료무료무료무료유료무료무료무료무료무료무료무료무료...
# 99  12977.8  158315000  무료무료무료무료무료무료무료유료무료무료무료무료무료무료유료무료무료무료무료무료무료무료무료...
#
# 컬럼                                                 가격  \
# 순서
# 0                                                   0
# 1                                                  00
# 2                                                 000
# 3                                                0000
# 4                                               00000
# ..                                                ...
# 95  0000000$4.99000000$1.9900000000$4.290000000$0....
# 96  0000000$4.99000000$1.9900000000$4.290000000$0....
# 97  0000000$4.99000000$1.9900000000$4.290000000$0....
# 98  0000000$4.99000000$1.9900000000$4.290000000$0....
# 99  0000000$4.99000000$1.9900000000$4.290000000$0....
#
# 컬럼                                                연령층  안드로이드 버전  업데이트_년도  \
# 순서
# 0                                                 전체가       4.0     2018
# 1                                              전체가전체가       8.0     4036
# 2                                           전체가전체가전체가      12.0     6054
# 3                                        전체가전체가전체가청소년      16.2     8072
# 4                                     전체가전체가전체가청소년전체가      20.6    10090
# ..                                                ...       ...      ...
# 95  전체가전체가전체가청소년전체가전체가전체가전체가전체가전체가전체가전체가청소년전체가전체가전...     369.3   193713
# 96  전체가전체가전체가청소년전체가전체가전체가전체가전체가전체가전체가전체가청소년전체가전체가전...     373.3   195731
# 97  전체가전체가전체가청소년전체가전체가전체가전체가전체가전체가전체가전체가청소년전체가전체가전...     377.3   197749
# 98  전체가전체가전체가청소년전체가전체가전체가전체가전체가전체가전체가전체가청소년전체가전체가전...     382.3   199767
# 99  전체가전체가전체가청소년전체가전체가전체가전체가전체가전체가전체가전체가청소년전체가전체가전...     386.4   201784
#
# 컬럼  업데이트_달    업데이트_년달    F  App
# 순서
# 0        1    2018.01  NaN    5
# 1        2    4036.02  NaN   10
# 2       10    6054.10  NaN   15
# 3       16    8072.16  NaN   20
# 4       22   10090.22  NaN   25
# ..     ...        ...  ...  ...
# 95     619  193719.19  NaN  480
# 96     622  195737.22  NaN  485
# 97     626  197755.26  NaN  490
# 98     634  199773.34  NaN  495
# 99     645  201790.45  NaN  500
#
# [100 rows x 15 columns]

# %%
data.apply(lambda x: x.max() - x.min())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-950c0c1258af> in <module>
# ----> 1 data.apply(lambda x: x.max() - x.min())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# ~\Anaconda3\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-14-950c0c1258af> in <lambda>(x)
# ----> 1 data.apply(lambda x: x.max() - x.min())
#
# TypeError: ("unsupported operand type(s) for -: 'str' and 'str'", 'occurred at index App')

# %% [markdown]
# ---
# <br><br><br><br><br>

# %% [markdown]
# **히스토그램 구하기**
# - 데이터의 값들의 빈도를 조사하여 히스토그램을 만들 수 있다
# - 참고: https://pandas.pydata.org/pandas-docs/stable/getting_started/basics.html#basics-discretization

# %%
data['등급'].hist()

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s.value_counts()
# Out:
# 5    3
# 2    2
# 1    2
# 6    1
# 4    1
# 3    1
# dtype: int64

# %%
s.value_counts().hist()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-5edff4f048fe> in <module>
# ----> 1 data.vaule_counts()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'vaule_counts'
