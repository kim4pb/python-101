# %% [markdown]
# # 4강. Pandas강의

# %%
# pandas 사용하기
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings

# %% [markdown]
# 판다스 공식문서 및 참고 링크
# - https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
# - https://dandyrilla.github.io/2017-08-12/pandas-10min/
# - https://doorbw.tistory.com/172

# %% [markdown]
# Pandas 자료구조
# - pandas에서는 기본적으로 정의되는 자료구조인 series와 Data Frame을 사용. 이 자료구조들은 빅데이터 분석에 있어서 높은 수준의 성능을 보여줌.

# %% [markdown]
# Series -> 코드 다 변경해야함.

# %%
# Series 정의하기

obj = pd.Series([4,7,-5,3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
# series 값 확인하기
obj.values
# Out:
# array([ 4,  7, -5,  3], dtype=int64)

# %%
# series의 인덱스만 확인하기
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# 인덱스를 바꿀 수 있다.
obj2 = pd.Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
# python의 dictionary 자료형을 Series data로 만들 수 있다.
# dictionary의 key가 Series의 index가 된다
sdata = {'Kim': 35000, 'Beomwoo': 67000, 'Joan': 12000, 'Choi': 4000}
obj3 = pd.Series(sdata)
obj3
# Out:
# Kim        35000
# Beomwoo    67000
# Joan       12000
# Choi        4000
# dtype: int64

# %%
obj3.name = 'Salary'
obj3.index.name = "Names"
obj3
# Out:
# Names
# Kim        35000
# Beomwoo    67000
# Joan       12000
# Choi        4000
# Name: Salary, dtype: int64

# %% [markdown]
# Data Frame -> 코드 다 변경해야함.

# %%
# Data Frame 정의하기
# 이전에 DataFrame에 들어갈 데이터를 정의해주어야 하는데,
# 이는 python의 dictionary 또는 numpy의 array로 정의할 수 있다.
data = {'name': ['Beomwoo', 'Beomwoo', 'Beomwoo', 'Kim', 'Park'],
        'year': [2013, 2014, 2015, 2016, 2015],
        'points': [1.5, 1.7, 3.6, 2.4, 2.9]}
df = pd.DataFrame(data)
df
# Out:
#       name  year  points
# 0  Beomwoo  2013     1.5
# 1  Beomwoo  2014     1.7
# 2  Beomwoo  2015     3.6
# 3      Kim  2016     2.4
# 4     Park  2015     2.9

# %%
# 행과 열의 구조를 가진 데이터가 생긴다.

# %%
# 데이터 읽기
data=pd.read_csv('googleplaystrore.csv')

# %%
data=data[:50]

# %%
# 상위 5개 데이터
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
# 하위 2개 데이터
data.tail(2)
# Out:
#                             App           Category  Rating Reviews  Size  \
# 48             How To Draw Food     ART_AND_DESIGN     4.3     845  7.9M
# 49  Monster Truck Stunt 3D 2019  AUTO_AND_VEHICLES     4.2     367   25M
#
#     Installs  Type Price Content Rating           Genres  Last Updated  \
# 48  100,000+  Free     0       Everyone     Art & Design  May 28, 2018
# 49  100,000+  Free     0       Everyone  Auto & Vehicles  May 10, 2018
#
#    Current Ver   Android Ver
# 48         1.0    2.3 and up
# 49         1.0  4.0.3 and up

# %%
# index ->  Data Frame 속성/행 방향의 index
data.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
# columns-> Data Frame 컬럼 / 열 방향의 index
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
# values ->  numpy 데이터를 보려면 -> 값 얻기
data.values
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1, '159', '19M', '10,000+', 'Free', '0',
#         'Everyone', 'Art & Design', 'January 7, 2018', '1.0.0',
#         '4.0.3 and up'],
#        ['Coloring book moana', 'ART_AND_DESIGN', 3.9, '967', '14M',
#         '500,000+', 'Free', '0', 'Everyone', 'Art & Design;Pretend Play',
#         'January 15, 2018', '2.0.0', '4.0.3 and up'],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7, '87510', '8.7M', '5,000,000+', 'Free',
#         '0', 'Everyone', 'Art & Design', 'August 1, 2018', '1.2.4',
#         '4.0.3 and up'],
#        ['Sketch - Draw & Paint', 'ART_AND_DESIGN', 4.5, '215644', '25M',
#         '50,000,000+', 'Free', '0', 'Teen', 'Art & Design',
#         'June 8, 2018', 'Varies with device', '4.2 and up'],
#        ['Pixel Draw - Number Art Coloring Book', 'ART_AND_DESIGN', 4.3,
#         '967', '2.8M', '100,000+', 'Free', '0', 'Everyone',
#         'Art & Design;Creativity', 'June 20, 2018', '1.1', '4.4 and up'],
#        ['Paper flowers instructions', 'ART_AND_DESIGN', 4.4, '167',
#         '5.6M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'March 26, 2017', '1.0', '2.3 and up'],
#        ['Smoke Effect Photo Maker - Smoke Editor', 'ART_AND_DESIGN', 3.8,
#         '178', '19M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'April 26, 2018', '1.1', '4.0.3 and up'],
#        ['Infinite Painter', 'ART_AND_DESIGN', 4.1, '36815', '29M',
#         '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'June 14, 2018', '6.1.61.1', '4.2 and up'],
#        ['Garden Coloring Book', 'ART_AND_DESIGN', 4.4, '13791', '33M',
#         '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'September 20, 2017', '2.9.2', '3.0 and up'],
#        ['Kids Paint Free - Drawing Fun', 'ART_AND_DESIGN', 4.7, '121',
#         '3.1M', '10,000+', 'Free', '0', 'Everyone',
#         'Art & Design;Creativity', 'July 3, 2018', '2.8', '4.0.3 and up'],
#        ['Text on Photo - Fonteee', 'ART_AND_DESIGN', 4.4, '13880', '28M',
#         '1,000,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'October 27, 2017', '1.0.4', '4.1 and up'],
#        ['Name Art Photo Editor - Focus n Filters', 'ART_AND_DESIGN', 4.4,
#         '8788', '12M', '1,000,000+', 'Free', '0', 'Everyone',
#         'Art & Design', 'July 31, 2018', '1.0.15', '4.0 and up'],
#        ['Tattoo Name On My Photo Editor', 'ART_AND_DESIGN', 4.2, '44829',
#         '20M', '10,000,000+', 'Free', '0', 'Teen', 'Art & Design',
#         'April 2, 2018', '3.8', '4.1 and up'],
#        ['Mandala Coloring Book', 'ART_AND_DESIGN', 4.6, '4326', '21M',
#         '100,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'June 26, 2018', '1.0.4', '4.4 and up'],
#        ['3D Color Pixel by Number - Sandbox Art Coloring',
#         'ART_AND_DESIGN', 4.4, '1518', '37M', '100,000+', 'Free', '0',
#         'Everyone', 'Art & Design', 'August 3, 2018', '1.2.3',
#         '2.3 and up'],
#        ['Learn To Draw Kawaii Characters', 'ART_AND_DESIGN', 3.2, '55',
#         '2.7M', '5,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'June 6, 2018', nan, '4.2 and up'],
#        ['Photo Designer - Write your name with shapes', 'ART_AND_DESIGN',
#         4.7, '3632', '5.5M', '500,000+', 'Free', '0', 'Everyone',
#         'Art & Design', 'July 31, 2018', '3.1', '4.1 and up'],
#        ['350 Diy Room Decor Ideas', 'ART_AND_DESIGN', 4.5, '27', '17M',
#         '10,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'November 7, 2017', '1.0', '2.3 and up'],
#        ['FlipaClip - Cartoon animation', 'ART_AND_DESIGN', 4.3, '194216',
#         '39M', '5,000,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'August 3, 2018', '2.2.5', '4.0.3 and up'],
#        ['ibis Paint X', 'ART_AND_DESIGN', 4.6, '224399', '31M',
#         '10,000,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'July 30, 2018', '5.5.4', '4.1 and up'],
#        ['Logo Maker - Small Business', 'ART_AND_DESIGN', 4.0, '450',
#         '14M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'April 20, 2018', '4.0', '4.1 and up'],
#        ["Boys Photo Editor - Six Pack & Men's Suit", 'ART_AND_DESIGN',
#         4.1, '654', '12M', '100,000+', 'Free', '0', 'Everyone',
#         'Art & Design', 'March 20, 2018', '1.1', '4.0.3 and up'],
#        ['Superheroes Wallpapers | 4K Backgrounds', 'ART_AND_DESIGN', 4.7,
#         '7699', '4.2M', '500,000+', 'Free', '0', 'Everyone 10+',
#         'Art & Design', 'July 12, 2018', '2.2.6.2', '4.0.3 and up'],
#        ['Mcqueen Coloring pages', 'ART_AND_DESIGN', nan, '61', '7.0M',
#         '100,000+', 'Free', '0', 'Everyone',
#         'Art & Design;Action & Adventure', 'March 7, 2018', '1.0.0',
#         '4.1 and up'],
#        ['HD Mickey Minnie Wallpapers', 'ART_AND_DESIGN', 4.7, '118',
#         '23M', '50,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'July 7, 2018', '1.1.3', '4.1 and up'],
#        ['Harley Quinn wallpapers HD', 'ART_AND_DESIGN', 4.8, '192',
#         '6.0M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'April 25, 2018', '1.5', '3.0 and up'],
#        ['Colorfit - Drawing & Coloring', 'ART_AND_DESIGN', 4.7, '20260',
#         '25M', '500,000+', 'Free', '0', 'Everyone',
#         'Art & Design;Creativity', 'October 11, 2017', '1.0.8',
#         '4.0.3 and up'],
#        ['Animated Photo Editor', 'ART_AND_DESIGN', 4.1, '203', '6.1M',
#         '100,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'March 21, 2018', '1.03', '4.0.3 and up'],
#        ['Pencil Sketch Drawing', 'ART_AND_DESIGN', 3.9, '136', '4.6M',
#         '10,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'July 12, 2018', '6.0', '2.3 and up'],
#        ['Easy Realistic Drawing Tutorial', 'ART_AND_DESIGN', 4.1, '223',
#         '4.2M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'August 22, 2017', '1.0', '2.3 and up'],
#        ['Pink Silver Bow Keyboard Theme', 'ART_AND_DESIGN', 4.2, '1120',
#         '9.2M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'July 12, 2018', '6.7.12.2018', '4.0.3 and up'],
#        ['Art Drawing Ideas', 'ART_AND_DESIGN', 4.1, '227', '5.2M',
#         '50,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'May 31, 2018', '1.2', '2.3 and up'],
#        ['Anime Manga Coloring Book', 'ART_AND_DESIGN', 4.5, '5035',
#         '11M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'July 19, 2018', '2.20', '4.0 and up'],
#        ['Easy Origami Ideas', 'ART_AND_DESIGN', 4.2, '1015', '11M',
#         '100,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'January 6, 2018', '1.1.0', '4.1 and up'],
#        ['I Creative Idea', 'ART_AND_DESIGN', 4.7, '353', '4.2M',
#         '10,000+', 'Free', '0', 'Teen', 'Art & Design', 'April 27, 2018',
#         '1.6', '4.1 and up'],
#        ['How to draw Ladybug and Cat Noir', 'ART_AND_DESIGN', 3.8, '564',
#         '9.2M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'July 11, 2018', '2.1', '4.1 and up'],
#        ['UNICORN - Color By Number & Pixel Art Coloring',
#         'ART_AND_DESIGN', 4.7, '8145', '24M', '500,000+', 'Free', '0',
#         'Everyone', 'Art & Design;Creativity', 'August 2, 2018', '1.0.9',
#         '4.4 and up'],
#        ['Floor Plan Creator', 'ART_AND_DESIGN', 4.1, '36639',
#         'Varies with device', '5,000,000+', 'Free', '0', 'Everyone',
#         'Art & Design', 'July 14, 2018', 'Varies with device',
#         '2.3.3 and up'],
#        ['PIP Camera - PIP Collage Maker', 'ART_AND_DESIGN', 4.7, '158',
#         '11M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'November 29, 2017', '1.3', '4.0.3 and up'],
#        ['How To Color Disney Princess - Coloring Pages',
#         'ART_AND_DESIGN', 4.0, '591', '9.4M', '500,000+', 'Free', '0',
#         'Everyone', 'Art & Design', 'March 31, 2018', '1', '4.0 and up'],
#        ['Drawing Clothes Fashion Ideas', 'ART_AND_DESIGN', 4.2, '117',
#         '15M', '10,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'July 20, 2018', '2.0.1', '4.0.3 and up'],
#        ['Sad Poetry Photo Frames 2018', 'ART_AND_DESIGN', 4.5, '176',
#         '10M', '100,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'April 2, 2018', '1.0', '4.0.3 and up'],
#        ['Textgram - write on photos', 'ART_AND_DESIGN', 4.4, '295221',
#         'Varies with device', '10,000,000+', 'Free', '0', 'Everyone',
#         'Art & Design', 'July 30, 2018', 'Varies with device',
#         'Varies with device'],
#        ['Paint Splash!', 'ART_AND_DESIGN', 3.8, '2206', '1.2M',
#         '100,000+', 'Free', '0', 'Everyone', 'Art & Design;Creativity',
#         'April 15, 2018', '1.46', '4.1 and up'],
#        ['Popsicle Sticks and Similar DIY Craft Ideas', 'ART_AND_DESIGN',
#         4.2, '26', '12M', '10,000+', 'Free', '0', 'Everyone',
#         'Art & Design', 'January 3, 2018', '1.0.0', '4.1 and up'],
#        ['Canva: Poster, banner, card maker & graphic design',
#         'ART_AND_DESIGN', 4.7, '174531', '24M', '10,000,000+', 'Free',
#         '0', 'Everyone', 'Art & Design', 'July 31, 2018', '1.6.1',
#         '4.1 and up'],
#        ['Install images with music to make video without Net - 2018',
#         'ART_AND_DESIGN', 4.6, '1070', '26M', '100,000+', 'Free', '0',
#         'Everyone', 'Art & Design', 'November 14, 2017', '1.6',
#         '4.1 and up'],
#        ['Little Teddy Bear Colouring Book Game', 'ART_AND_DESIGN', 4.2,
#         '85', '8.0M', '100,000+', 'Free', '0', 'Everyone',
#         'Art & Design', 'December 17, 2017', '2.0.0', '4.1 and up'],
#        ['How To Draw Food', 'ART_AND_DESIGN', 4.3, '845', '7.9M',
#         '100,000+', 'Free', '0', 'Everyone', 'Art & Design',
#         'May 28, 2018', '1.0', '2.3 and up'],
#        ['Monster Truck Stunt 3D 2019', 'AUTO_AND_VEHICLES', 4.2, '367',
#         '25M', '100,000+', 'Free', '0', 'Everyone', 'Auto & Vehicles',
#         'May 10, 2018', '1.0', '4.0.3 and up']], dtype=object)

# %%
# .T 속성 -> Transpose index and columns. => index와 column 바꾼 형태.
data.T
# Out:
# name                                                        0   \
# index
# App             Photo Editor & Candy Camera & Grid & ScrapBook
# Category                                        ART_AND_DESIGN
# Rating                                                     4.1
# Reviews                                                    159
# Size                                                       19M
# Installs                                               10,000+
# Type                                                      Free
# Price                                                        0
# Content Rating                                        Everyone
# Genres                                            Art & Design
# Last Updated                                   January 7, 2018
# Current Ver                                              1.0.0
# Android Ver                                       4.0.3 and up
#
# name                                   1   \
# index
# App                   Coloring book moana
# Category                   ART_AND_DESIGN
# Rating                                3.9
# Reviews                               967
# Size                                  14M
# Installs                         500,000+
# Type                                 Free
# Price                                   0
# Content Rating                   Everyone
# Genres          Art & Design;Pretend Play
# Last Updated             January 15, 2018
# Current Ver                         2.0.0
# Android Ver                  4.0.3 and up
#
# name                                                           2   \
# index
# App             U Launcher Lite – FREE Live Cool Themes, Hide ...
# Category                                           ART_AND_DESIGN
# Rating                                                        4.7
# Reviews                                                     87510
# Size                                                         8.7M
# Installs                                               5,000,000+
# Type                                                         Free
# Price                                                           0
# Content Rating                                           Everyone
# Genres                                               Art & Design
# Last Updated                                       August 1, 2018
# Current Ver                                                 1.2.4
# Android Ver                                          4.0.3 and up
#
# name                               3                                      4   \
# index
# App             Sketch - Draw & Paint  Pixel Draw - Number Art Coloring Book
# Category               ART_AND_DESIGN                         ART_AND_DESIGN
# Rating                            4.5                                    4.3
# Reviews                        215644                                    967
# Size                              25M                                   2.8M
# Installs                  50,000,000+                               100,000+
# Type                             Free                                   Free
# Price                               0                                      0
# Content Rating                   Teen                               Everyone
# Genres                   Art & Design                Art & Design;Creativity
# Last Updated             June 8, 2018                          June 20, 2018
# Current Ver        Varies with device                                    1.1
# Android Ver                4.2 and up                             4.4 and up
#
# name                                    5   \
# index
# App             Paper flowers instructions
# Category                    ART_AND_DESIGN
# Rating                                 4.4
# Reviews                                167
# Size                                  5.6M
# Installs                           50,000+
# Type                                  Free
# Price                                    0
# Content Rating                    Everyone
# Genres                        Art & Design
# Last Updated                March 26, 2017
# Current Ver                            1.0
# Android Ver                     2.3 and up
#
# name                                                 6                 7   \
# index
# App             Smoke Effect Photo Maker - Smoke Editor  Infinite Painter
# Category                                 ART_AND_DESIGN    ART_AND_DESIGN
# Rating                                              3.8               4.1
# Reviews                                             178             36815
# Size                                                19M               29M
# Installs                                        50,000+        1,000,000+
# Type                                               Free              Free
# Price                                                 0                 0
# Content Rating                                 Everyone          Everyone
# Genres                                     Art & Design      Art & Design
# Last Updated                             April 26, 2018     June 14, 2018
# Current Ver                                         1.1          6.1.61.1
# Android Ver                                4.0.3 and up        4.2 and up
#
# name                              8                              9   ...  \
# index                                                                ...
# App             Garden Coloring Book  Kids Paint Free - Drawing Fun  ...
# Category              ART_AND_DESIGN                 ART_AND_DESIGN  ...
# Rating                           4.4                            4.7  ...
# Reviews                        13791                            121  ...
# Size                             33M                           3.1M  ...
# Installs                  1,000,000+                        10,000+  ...
# Type                            Free                           Free  ...
# Price                              0                              0  ...
# Content Rating              Everyone                       Everyone  ...
# Genres                  Art & Design        Art & Design;Creativity  ...
# Last Updated      September 20, 2017                   July 3, 2018  ...
# Current Ver                    2.9.2                            2.8  ...
# Android Ver               3.0 and up                   4.0.3 and up  ...
#
# name                                       40                            41  \
# index
# App             Drawing Clothes Fashion Ideas  Sad Poetry Photo Frames 2018
# Category                       ART_AND_DESIGN                ART_AND_DESIGN
# Rating                                    4.2                           4.5
# Reviews                                   117                           176
# Size                                      15M                           10M
# Installs                              10,000+                      100,000+
# Type                                     Free                          Free
# Price                                       0                             0
# Content Rating                       Everyone                      Everyone
# Genres                           Art & Design                  Art & Design
# Last Updated                    July 20, 2018                 April 2, 2018
# Current Ver                             2.0.1                           1.0
# Android Ver                      4.0.3 and up                  4.0.3 and up
#
# name                                    42                       43  \
# index
# App             Textgram - write on photos            Paint Splash!
# Category                    ART_AND_DESIGN           ART_AND_DESIGN
# Rating                                 4.4                      3.8
# Reviews                             295221                     2206
# Size                    Varies with device                     1.2M
# Installs                       10,000,000+                 100,000+
# Type                                  Free                     Free
# Price                                    0                        0
# Content Rating                    Everyone                 Everyone
# Genres                        Art & Design  Art & Design;Creativity
# Last Updated                 July 30, 2018           April 15, 2018
# Current Ver             Varies with device                     1.46
# Android Ver             Varies with device               4.1 and up
#
# name                                                     44  \
# index
# App             Popsicle Sticks and Similar DIY Craft Ideas
# Category                                     ART_AND_DESIGN
# Rating                                                  4.2
# Reviews                                                  26
# Size                                                    12M
# Installs                                            10,000+
# Type                                                   Free
# Price                                                     0
# Content Rating                                     Everyone
# Genres                                         Art & Design
# Last Updated                                January 3, 2018
# Current Ver                                           1.0.0
# Android Ver                                      4.1 and up
#
# name                                                           45  \
# index
# App             Canva: Poster, banner, card maker & graphic de...
# Category                                           ART_AND_DESIGN
# Rating                                                        4.7
# Reviews                                                    174531
# Size                                                          24M
# Installs                                              10,000,000+
# Type                                                         Free
# Price                                                           0
# Content Rating                                           Everyone
# Genres                                               Art & Design
# Last Updated                                        July 31, 2018
# Current Ver                                                 1.6.1
# Android Ver                                            4.1 and up
#
# name                                                           46  \
# index
# App             Install images with music to make video withou...
# Category                                           ART_AND_DESIGN
# Rating                                                        4.6
# Reviews                                                      1070
# Size                                                          26M
# Installs                                                 100,000+
# Type                                                         Free
# Price                                                           0
# Content Rating                                           Everyone
# Genres                                               Art & Design
# Last Updated                                    November 14, 2017
# Current Ver                                                   1.6
# Android Ver                                            4.1 and up
#
# name                                               47                48  \
# index
# App             Little Teddy Bear Colouring Book Game  How To Draw Food
# Category                               ART_AND_DESIGN    ART_AND_DESIGN
# Rating                                            4.2               4.3
# Reviews                                            85               845
# Size                                             8.0M              7.9M
# Installs                                     100,000+          100,000+
# Type                                             Free              Free
# Price                                               0                 0
# Content Rating                               Everyone          Everyone
# Genres                                   Art & Design      Art & Design
# Last Updated                        December 17, 2017      May 28, 2018
# Current Ver                                     2.0.0               1.0
# Android Ver                                4.1 and up        2.3 and up
#
# name                                     49
# index
# App             Monster Truck Stunt 3D 2019
# Category                  AUTO_AND_VEHICLES
# Rating                                  4.2
# Reviews                                 367
# Size                                    25M
# Installs                           100,000+
# Type                                   Free
# Price                                     0
# Content Rating                     Everyone
# Genres                      Auto & Vehicles
# Last Updated                   May 10, 2018
# Current Ver                             1.0
# Android Ver                    4.0.3 and up
#
# [13 rows x 50 columns]

# %%
# 각 인덱스에 대한 이름 설정하기
data.index.name = 'name'
data.columns.name = 'index'
data
# Out:
# index                                                App           Category  \
# name
# 0         Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                    Coloring book moana     ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint     ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                             Paper flowers instructions     ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                       Infinite Painter     ART_AND_DESIGN
# 8                                   Garden Coloring Book     ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                               Text on Photo - Fonteee     ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor     ART_AND_DESIGN
# 13                                 Mandala Coloring Book     ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring     ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters     ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes     ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas     ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation     ART_AND_DESIGN
# 19                                          ibis Paint X     ART_AND_DESIGN
# 20                           Logo Maker - Small Business     ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit     ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds     ART_AND_DESIGN
# 23                                Mcqueen Coloring pages     ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers     ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD     ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring     ART_AND_DESIGN
# 27                                 Animated Photo Editor     ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing     ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial     ART_AND_DESIGN
# 30                        Pink Silver Bow Keyboard Theme     ART_AND_DESIGN
# 31                                     Art Drawing Ideas     ART_AND_DESIGN
# 32                             Anime Manga Coloring Book     ART_AND_DESIGN
# 33                                    Easy Origami Ideas     ART_AND_DESIGN
# 34                                       I Creative Idea     ART_AND_DESIGN
# 35                      How to draw Ladybug and Cat Noir     ART_AND_DESIGN
# 36        UNICORN - Color By Number & Pixel Art Coloring     ART_AND_DESIGN
# 37                                    Floor Plan Creator     ART_AND_DESIGN
# 38                        PIP Camera - PIP Collage Maker     ART_AND_DESIGN
# 39         How To Color Disney Princess - Coloring Pages     ART_AND_DESIGN
# 40                         Drawing Clothes Fashion Ideas     ART_AND_DESIGN
# 41                          Sad Poetry Photo Frames 2018     ART_AND_DESIGN
# 42                            Textgram - write on photos     ART_AND_DESIGN
# 43                                         Paint Splash!     ART_AND_DESIGN
# 44           Popsicle Sticks and Similar DIY Craft Ideas     ART_AND_DESIGN
# 45     Canva: Poster, banner, card maker & graphic de...     ART_AND_DESIGN
# 46     Install images with music to make video withou...     ART_AND_DESIGN
# 47                 Little Teddy Bear Colouring Book Game     ART_AND_DESIGN
# 48                                      How To Draw Food     ART_AND_DESIGN
# 49                           Monster Truck Stunt 3D 2019  AUTO_AND_VEHICLES
#
# index  Rating Reviews                Size     Installs  Type Price  \
# name
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# 5         4.4     167                5.6M      50,000+  Free     0
# 6         3.8     178                 19M      50,000+  Free     0
# 7         4.1   36815                 29M   1,000,000+  Free     0
# 8         4.4   13791                 33M   1,000,000+  Free     0
# 9         4.7     121                3.1M      10,000+  Free     0
# 10        4.4   13880                 28M   1,000,000+  Free     0
# 11        4.4    8788                 12M   1,000,000+  Free     0
# 12        4.2   44829                 20M  10,000,000+  Free     0
# 13        4.6    4326                 21M     100,000+  Free     0
# 14        4.4    1518                 37M     100,000+  Free     0
# 15        3.2      55                2.7M       5,000+  Free     0
# 16        4.7    3632                5.5M     500,000+  Free     0
# 17        4.5      27                 17M      10,000+  Free     0
# 18        4.3  194216                 39M   5,000,000+  Free     0
# 19        4.6  224399                 31M  10,000,000+  Free     0
# 20        4.0     450                 14M     100,000+  Free     0
# 21        4.1     654                 12M     100,000+  Free     0
# 22        4.7    7699                4.2M     500,000+  Free     0
# 23        NaN      61                7.0M     100,000+  Free     0
# 24        4.7     118                 23M      50,000+  Free     0
# 25        4.8     192                6.0M      10,000+  Free     0
# 26        4.7   20260                 25M     500,000+  Free     0
# 27        4.1     203                6.1M     100,000+  Free     0
# 28        3.9     136                4.6M      10,000+  Free     0
# 29        4.1     223                4.2M     100,000+  Free     0
# 30        4.2    1120                9.2M     100,000+  Free     0
# 31        4.1     227                5.2M      50,000+  Free     0
# 32        4.5    5035                 11M     100,000+  Free     0
# 33        4.2    1015                 11M     100,000+  Free     0
# 34        4.7     353                4.2M      10,000+  Free     0
# 35        3.8     564                9.2M     100,000+  Free     0
# 36        4.7    8145                 24M     500,000+  Free     0
# 37        4.1   36639  Varies with device   5,000,000+  Free     0
# 38        4.7     158                 11M      10,000+  Free     0
# 39        4.0     591                9.4M     500,000+  Free     0
# 40        4.2     117                 15M      10,000+  Free     0
# 41        4.5     176                 10M     100,000+  Free     0
# 42        4.4  295221  Varies with device  10,000,000+  Free     0
# 43        3.8    2206                1.2M     100,000+  Free     0
# 44        4.2      26                 12M      10,000+  Free     0
# 45        4.7  174531                 24M  10,000,000+  Free     0
# 46        4.6    1070                 26M     100,000+  Free     0
# 47        4.2      85                8.0M     100,000+  Free     0
# 48        4.3     845                7.9M     100,000+  Free     0
# 49        4.2     367                 25M     100,000+  Free     0
#
# index Content Rating                           Genres        Last Updated  \
# name
# 0           Everyone                     Art & Design     January 7, 2018
# 1           Everyone        Art & Design;Pretend Play    January 15, 2018
# 2           Everyone                     Art & Design      August 1, 2018
# 3               Teen                     Art & Design        June 8, 2018
# 4           Everyone          Art & Design;Creativity       June 20, 2018
# 5           Everyone                     Art & Design      March 26, 2017
# 6           Everyone                     Art & Design      April 26, 2018
# 7           Everyone                     Art & Design       June 14, 2018
# 8           Everyone                     Art & Design  September 20, 2017
# 9           Everyone          Art & Design;Creativity        July 3, 2018
# 10          Everyone                     Art & Design    October 27, 2017
# 11          Everyone                     Art & Design       July 31, 2018
# 12              Teen                     Art & Design       April 2, 2018
# 13          Everyone                     Art & Design       June 26, 2018
# 14          Everyone                     Art & Design      August 3, 2018
# 15          Everyone                     Art & Design        June 6, 2018
# 16          Everyone                     Art & Design       July 31, 2018
# 17          Everyone                     Art & Design    November 7, 2017
# 18          Everyone                     Art & Design      August 3, 2018
# 19          Everyone                     Art & Design       July 30, 2018
# 20          Everyone                     Art & Design      April 20, 2018
# 21          Everyone                     Art & Design      March 20, 2018
# 22      Everyone 10+                     Art & Design       July 12, 2018
# 23          Everyone  Art & Design;Action & Adventure       March 7, 2018
# 24          Everyone                     Art & Design        July 7, 2018
# 25          Everyone                     Art & Design      April 25, 2018
# 26          Everyone          Art & Design;Creativity    October 11, 2017
# 27          Everyone                     Art & Design      March 21, 2018
# 28          Everyone                     Art & Design       July 12, 2018
# 29          Everyone                     Art & Design     August 22, 2017
# 30          Everyone                     Art & Design       July 12, 2018
# 31          Everyone                     Art & Design        May 31, 2018
# 32          Everyone                     Art & Design       July 19, 2018
# 33          Everyone                     Art & Design     January 6, 2018
# 34              Teen                     Art & Design      April 27, 2018
# 35          Everyone                     Art & Design       July 11, 2018
# 36          Everyone          Art & Design;Creativity      August 2, 2018
# 37          Everyone                     Art & Design       July 14, 2018
# 38          Everyone                     Art & Design   November 29, 2017
# 39          Everyone                     Art & Design      March 31, 2018
# 40          Everyone                     Art & Design       July 20, 2018
# 41          Everyone                     Art & Design       April 2, 2018
# 42          Everyone                     Art & Design       July 30, 2018
# 43          Everyone          Art & Design;Creativity      April 15, 2018
# 44          Everyone                     Art & Design     January 3, 2018
# 45          Everyone                     Art & Design       July 31, 2018
# 46          Everyone                     Art & Design   November 14, 2017
# 47          Everyone                     Art & Design   December 17, 2017
# 48          Everyone                     Art & Design        May 28, 2018
# 49          Everyone                  Auto & Vehicles        May 10, 2018
#
# index         Current Ver         Android Ver
# name
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# 5                     1.0          2.3 and up
# 6                     1.1        4.0.3 and up
# 7                6.1.61.1          4.2 and up
# 8                   2.9.2          3.0 and up
# 9                     2.8        4.0.3 and up
# 10                  1.0.4          4.1 and up
# 11                 1.0.15          4.0 and up
# 12                    3.8          4.1 and up
# 13                  1.0.4          4.4 and up
# 14                  1.2.3          2.3 and up
# 15                    NaN          4.2 and up
# 16                    3.1          4.1 and up
# 17                    1.0          2.3 and up
# 18                  2.2.5        4.0.3 and up
# 19                  5.5.4          4.1 and up
# 20                    4.0          4.1 and up
# 21                    1.1        4.0.3 and up
# 22                2.2.6.2        4.0.3 and up
# 23                  1.0.0          4.1 and up
# 24                  1.1.3          4.1 and up
# 25                    1.5          3.0 and up
# 26                  1.0.8        4.0.3 and up
# 27                   1.03        4.0.3 and up
# 28                    6.0          2.3 and up
# 29                    1.0          2.3 and up
# 30            6.7.12.2018        4.0.3 and up
# 31                    1.2          2.3 and up
# 32                   2.20          4.0 and up
# 33                  1.1.0          4.1 and up
# 34                    1.6          4.1 and up
# 35                    2.1          4.1 and up
# 36                  1.0.9          4.4 and up
# 37     Varies with device        2.3.3 and up
# 38                    1.3        4.0.3 and up
# 39                      1          4.0 and up
# 40                  2.0.1        4.0.3 and up
# 41                    1.0        4.0.3 and up
# 42     Varies with device  Varies with device
# 43                   1.46          4.1 and up
# 44                  1.0.0          4.1 and up
# 45                  1.6.1          4.1 and up
# 46                    1.6          4.1 and up
# 47                  2.0.0          4.1 and up
# 48                    1.0          2.3 and up
# 49                    1.0        4.0.3 and up

# %%
# describe() 함수 -> data frame의 간단한 통계 정보를 알려준다. 
data.describe()
# Out:
# index     Rating
# count  49.000000
# mean    4.314286
# std     0.327236
# min     3.200000
# 25%     4.100000
# 50%     4.300000
# 75%     4.600000
# max     4.800000

# %%
# DataFrame을 만들면서 columns와 index를 설정할 수 있다.
df2 = pd.DataFrame(data, columns=['year', 'name', 'points', 'penalty'],
                  index=['one', 'two', 'three', 'four', 'five'])
df2
# Out:
#        year  name  points  penalty
# one     NaN   NaN     NaN      NaN
# two     NaN   NaN     NaN      NaN
# three   NaN   NaN     NaN      NaN
# four    NaN   NaN     NaN      NaN
# five    NaN   NaN     NaN      NaN

# %%
# DataFrame을 만들면서 columns와 index를 설정할 수 있다.
data2 = pd.DataFrame(data, columns=['year', 'name', 'points', 'penalty'],
                  index=['one', 'two', 'three', 'four', 'five'])
df2

# %% [markdown]
# **정렬 .sort_inex()** -> 행과 열 이름 정렬
#
# 정렬할 대상 축을 결정할 때, axis.
# - axis = 0 => 인덱스 기준 정렬(기본값)
# - axis = 1 => 컬럼 기준.
#
# 정렬의 방향에 대한 파라미터, ascending.
# - ascending = True 오름차순(기본값)
# - ascending = False 내림차순

# %%
# 내림차순 정렬 예시
data.sort_index(axis=1, ascending=False)
# Out:
# index  Type                Size Reviews  Rating Price        Last Updated  \
# name
# 0      Free                 19M     159     4.1     0     January 7, 2018
# 1      Free                 14M     967     3.9     0    January 15, 2018
# 2      Free                8.7M   87510     4.7     0      August 1, 2018
# 3      Free                 25M  215644     4.5     0        June 8, 2018
# 4      Free                2.8M     967     4.3     0       June 20, 2018
# 5      Free                5.6M     167     4.4     0      March 26, 2017
# 6      Free                 19M     178     3.8     0      April 26, 2018
# 7      Free                 29M   36815     4.1     0       June 14, 2018
# 8      Free                 33M   13791     4.4     0  September 20, 2017
# 9      Free                3.1M     121     4.7     0        July 3, 2018
# 10     Free                 28M   13880     4.4     0    October 27, 2017
# 11     Free                 12M    8788     4.4     0       July 31, 2018
# 12     Free                 20M   44829     4.2     0       April 2, 2018
# 13     Free                 21M    4326     4.6     0       June 26, 2018
# 14     Free                 37M    1518     4.4     0      August 3, 2018
# 15     Free                2.7M      55     3.2     0        June 6, 2018
# 16     Free                5.5M    3632     4.7     0       July 31, 2018
# 17     Free                 17M      27     4.5     0    November 7, 2017
# 18     Free                 39M  194216     4.3     0      August 3, 2018
# 19     Free                 31M  224399     4.6     0       July 30, 2018
# 20     Free                 14M     450     4.0     0      April 20, 2018
# 21     Free                 12M     654     4.1     0      March 20, 2018
# 22     Free                4.2M    7699     4.7     0       July 12, 2018
# 23     Free                7.0M      61     NaN     0       March 7, 2018
# 24     Free                 23M     118     4.7     0        July 7, 2018
# 25     Free                6.0M     192     4.8     0      April 25, 2018
# 26     Free                 25M   20260     4.7     0    October 11, 2017
# 27     Free                6.1M     203     4.1     0      March 21, 2018
# 28     Free                4.6M     136     3.9     0       July 12, 2018
# 29     Free                4.2M     223     4.1     0     August 22, 2017
# 30     Free                9.2M    1120     4.2     0       July 12, 2018
# 31     Free                5.2M     227     4.1     0        May 31, 2018
# 32     Free                 11M    5035     4.5     0       July 19, 2018
# 33     Free                 11M    1015     4.2     0     January 6, 2018
# 34     Free                4.2M     353     4.7     0      April 27, 2018
# 35     Free                9.2M     564     3.8     0       July 11, 2018
# 36     Free                 24M    8145     4.7     0      August 2, 2018
# 37     Free  Varies with device   36639     4.1     0       July 14, 2018
# 38     Free                 11M     158     4.7     0   November 29, 2017
# 39     Free                9.4M     591     4.0     0      March 31, 2018
# 40     Free                 15M     117     4.2     0       July 20, 2018
# 41     Free                 10M     176     4.5     0       April 2, 2018
# 42     Free  Varies with device  295221     4.4     0       July 30, 2018
# 43     Free                1.2M    2206     3.8     0      April 15, 2018
# 44     Free                 12M      26     4.2     0     January 3, 2018
# 45     Free                 24M  174531     4.7     0       July 31, 2018
# 46     Free                 26M    1070     4.6     0   November 14, 2017
# 47     Free                8.0M      85     4.2     0   December 17, 2017
# 48     Free                7.9M     845     4.3     0        May 28, 2018
# 49     Free                 25M     367     4.2     0        May 10, 2018
#
# index     Installs                           Genres         Current Ver  \
# name
# 0          10,000+                     Art & Design               1.0.0
# 1         500,000+        Art & Design;Pretend Play               2.0.0
# 2       5,000,000+                     Art & Design               1.2.4
# 3      50,000,000+                     Art & Design  Varies with device
# 4         100,000+          Art & Design;Creativity                 1.1
# 5          50,000+                     Art & Design                 1.0
# 6          50,000+                     Art & Design                 1.1
# 7       1,000,000+                     Art & Design            6.1.61.1
# 8       1,000,000+                     Art & Design               2.9.2
# 9          10,000+          Art & Design;Creativity                 2.8
# 10      1,000,000+                     Art & Design               1.0.4
# 11      1,000,000+                     Art & Design              1.0.15
# 12     10,000,000+                     Art & Design                 3.8
# 13        100,000+                     Art & Design               1.0.4
# 14        100,000+                     Art & Design               1.2.3
# 15          5,000+                     Art & Design                 NaN
# 16        500,000+                     Art & Design                 3.1
# 17         10,000+                     Art & Design                 1.0
# 18      5,000,000+                     Art & Design               2.2.5
# 19     10,000,000+                     Art & Design               5.5.4
# 20        100,000+                     Art & Design                 4.0
# 21        100,000+                     Art & Design                 1.1
# 22        500,000+                     Art & Design             2.2.6.2
# 23        100,000+  Art & Design;Action & Adventure               1.0.0
# 24         50,000+                     Art & Design               1.1.3
# 25         10,000+                     Art & Design                 1.5
# 26        500,000+          Art & Design;Creativity               1.0.8
# 27        100,000+                     Art & Design                1.03
# 28         10,000+                     Art & Design                 6.0
# 29        100,000+                     Art & Design                 1.0
# 30        100,000+                     Art & Design         6.7.12.2018
# 31         50,000+                     Art & Design                 1.2
# 32        100,000+                     Art & Design                2.20
# 33        100,000+                     Art & Design               1.1.0
# 34         10,000+                     Art & Design                 1.6
# 35        100,000+                     Art & Design                 2.1
# 36        500,000+          Art & Design;Creativity               1.0.9
# 37      5,000,000+                     Art & Design  Varies with device
# 38         10,000+                     Art & Design                 1.3
# 39        500,000+                     Art & Design                   1
# 40         10,000+                     Art & Design               2.0.1
# 41        100,000+                     Art & Design                 1.0
# 42     10,000,000+                     Art & Design  Varies with device
# 43        100,000+          Art & Design;Creativity                1.46
# 44         10,000+                     Art & Design               1.0.0
# 45     10,000,000+                     Art & Design               1.6.1
# 46        100,000+                     Art & Design                 1.6
# 47        100,000+                     Art & Design               2.0.0
# 48        100,000+                     Art & Design                 1.0
# 49        100,000+                  Auto & Vehicles                 1.0
#
# index Content Rating           Category  \
# name
# 0           Everyone     ART_AND_DESIGN
# 1           Everyone     ART_AND_DESIGN
# 2           Everyone     ART_AND_DESIGN
# 3               Teen     ART_AND_DESIGN
# 4           Everyone     ART_AND_DESIGN
# 5           Everyone     ART_AND_DESIGN
# 6           Everyone     ART_AND_DESIGN
# 7           Everyone     ART_AND_DESIGN
# 8           Everyone     ART_AND_DESIGN
# 9           Everyone     ART_AND_DESIGN
# 10          Everyone     ART_AND_DESIGN
# 11          Everyone     ART_AND_DESIGN
# 12              Teen     ART_AND_DESIGN
# 13          Everyone     ART_AND_DESIGN
# 14          Everyone     ART_AND_DESIGN
# 15          Everyone     ART_AND_DESIGN
# 16          Everyone     ART_AND_DESIGN
# 17          Everyone     ART_AND_DESIGN
# 18          Everyone     ART_AND_DESIGN
# 19          Everyone     ART_AND_DESIGN
# 20          Everyone     ART_AND_DESIGN
# 21          Everyone     ART_AND_DESIGN
# 22      Everyone 10+     ART_AND_DESIGN
# 23          Everyone     ART_AND_DESIGN
# 24          Everyone     ART_AND_DESIGN
# 25          Everyone     ART_AND_DESIGN
# 26          Everyone     ART_AND_DESIGN
# 27          Everyone     ART_AND_DESIGN
# 28          Everyone     ART_AND_DESIGN
# 29          Everyone     ART_AND_DESIGN
# 30          Everyone     ART_AND_DESIGN
# 31          Everyone     ART_AND_DESIGN
# 32          Everyone     ART_AND_DESIGN
# 33          Everyone     ART_AND_DESIGN
# 34              Teen     ART_AND_DESIGN
# 35          Everyone     ART_AND_DESIGN
# 36          Everyone     ART_AND_DESIGN
# 37          Everyone     ART_AND_DESIGN
# 38          Everyone     ART_AND_DESIGN
# 39          Everyone     ART_AND_DESIGN
# 40          Everyone     ART_AND_DESIGN
# 41          Everyone     ART_AND_DESIGN
# 42          Everyone     ART_AND_DESIGN
# 43          Everyone     ART_AND_DESIGN
# 44          Everyone     ART_AND_DESIGN
# 45          Everyone     ART_AND_DESIGN
# 46          Everyone     ART_AND_DESIGN
# 47          Everyone     ART_AND_DESIGN
# 48          Everyone     ART_AND_DESIGN
# 49          Everyone  AUTO_AND_VEHICLES
#
# index                                                App         Android Ver
# name
# 0         Photo Editor & Candy Camera & Grid & ScrapBook        4.0.3 and up
# 1                                    Coloring book moana        4.0.3 and up
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...        4.0.3 and up
# 3                                  Sketch - Draw & Paint          4.2 and up
# 4                  Pixel Draw - Number Art Coloring Book          4.4 and up
# 5                             Paper flowers instructions          2.3 and up
# 6                Smoke Effect Photo Maker - Smoke Editor        4.0.3 and up
# 7                                       Infinite Painter          4.2 and up
# 8                                   Garden Coloring Book          3.0 and up
# 9                          Kids Paint Free - Drawing Fun        4.0.3 and up
# 10                               Text on Photo - Fonteee          4.1 and up
# 11               Name Art Photo Editor - Focus n Filters          4.0 and up
# 12                        Tattoo Name On My Photo Editor          4.1 and up
# 13                                 Mandala Coloring Book          4.4 and up
# 14       3D Color Pixel by Number - Sandbox Art Coloring          2.3 and up
# 15                       Learn To Draw Kawaii Characters          4.2 and up
# 16          Photo Designer - Write your name with shapes          4.1 and up
# 17                              350 Diy Room Decor Ideas          2.3 and up
# 18                         FlipaClip - Cartoon animation        4.0.3 and up
# 19                                          ibis Paint X          4.1 and up
# 20                           Logo Maker - Small Business          4.1 and up
# 21             Boys Photo Editor - Six Pack & Men's Suit        4.0.3 and up
# 22               Superheroes Wallpapers | 4K Backgrounds        4.0.3 and up
# 23                                Mcqueen Coloring pages          4.1 and up
# 24                           HD Mickey Minnie Wallpapers          4.1 and up
# 25                            Harley Quinn wallpapers HD          3.0 and up
# 26                         Colorfit - Drawing & Coloring        4.0.3 and up
# 27                                 Animated Photo Editor        4.0.3 and up
# 28                                 Pencil Sketch Drawing          2.3 and up
# 29                       Easy Realistic Drawing Tutorial          2.3 and up
# 30                        Pink Silver Bow Keyboard Theme        4.0.3 and up
# 31                                     Art Drawing Ideas          2.3 and up
# 32                             Anime Manga Coloring Book          4.0 and up
# 33                                    Easy Origami Ideas          4.1 and up
# 34                                       I Creative Idea          4.1 and up
# 35                      How to draw Ladybug and Cat Noir          4.1 and up
# 36        UNICORN - Color By Number & Pixel Art Coloring          4.4 and up
# 37                                    Floor Plan Creator        2.3.3 and up
# 38                        PIP Camera - PIP Collage Maker        4.0.3 and up
# 39         How To Color Disney Princess - Coloring Pages          4.0 and up
# 40                         Drawing Clothes Fashion Ideas        4.0.3 and up
# 41                          Sad Poetry Photo Frames 2018        4.0.3 and up
# 42                            Textgram - write on photos  Varies with device
# 43                                         Paint Splash!          4.1 and up
# 44           Popsicle Sticks and Similar DIY Craft Ideas          4.1 and up
# 45     Canva: Poster, banner, card maker & graphic de...          4.1 and up
# 46     Install images with music to make video withou...          4.1 and up
# 47                 Little Teddy Bear Colouring Book Game          4.1 and up
# 48                                      How To Draw Food          2.3 and up
# 49                           Monster Truck Stunt 3D 2019        4.0.3 and up

# %%
# DataFrame 내부 값 정렬. -> 정렬 기준
data.sort_values(by='Rating')
# Out:
# index                                                App           Category  \
# name
# 15                       Learn To Draw Kawaii Characters     ART_AND_DESIGN
# 43                                         Paint Splash!     ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 35                      How to draw Ladybug and Cat Noir     ART_AND_DESIGN
# 1                                    Coloring book moana     ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing     ART_AND_DESIGN
# 20                           Logo Maker - Small Business     ART_AND_DESIGN
# 39         How To Color Disney Princess - Coloring Pages     ART_AND_DESIGN
# 27                                 Animated Photo Editor     ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial     ART_AND_DESIGN
# 31                                     Art Drawing Ideas     ART_AND_DESIGN
# 0         Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit     ART_AND_DESIGN
# 7                                       Infinite Painter     ART_AND_DESIGN
# 37                                    Floor Plan Creator     ART_AND_DESIGN
# 30                        Pink Silver Bow Keyboard Theme     ART_AND_DESIGN
# 40                         Drawing Clothes Fashion Ideas     ART_AND_DESIGN
# 44           Popsicle Sticks and Similar DIY Craft Ideas     ART_AND_DESIGN
# 47                 Little Teddy Bear Colouring Book Game     ART_AND_DESIGN
# 33                                    Easy Origami Ideas     ART_AND_DESIGN
# 49                           Monster Truck Stunt 3D 2019  AUTO_AND_VEHICLES
# 12                        Tattoo Name On My Photo Editor     ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation     ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 48                                      How To Draw Food     ART_AND_DESIGN
# 42                            Textgram - write on photos     ART_AND_DESIGN
# 5                             Paper flowers instructions     ART_AND_DESIGN
# 8                                   Garden Coloring Book     ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# 10                               Text on Photo - Fonteee     ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring     ART_AND_DESIGN
# 32                             Anime Manga Coloring Book     ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint     ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas     ART_AND_DESIGN
# 41                          Sad Poetry Photo Frames 2018     ART_AND_DESIGN
# 46     Install images with music to make video withou...     ART_AND_DESIGN
# 19                                          ibis Paint X     ART_AND_DESIGN
# 13                                 Mandala Coloring Book     ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 45     Canva: Poster, banner, card maker & graphic de...     ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds     ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring     ART_AND_DESIGN
# 38                        PIP Camera - PIP Collage Maker     ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 36        UNICORN - Color By Number & Pixel Art Coloring     ART_AND_DESIGN
# 34                                       I Creative Idea     ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes     ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers     ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD     ART_AND_DESIGN
# 23                                Mcqueen Coloring pages     ART_AND_DESIGN
#
# index  Rating Reviews                Size     Installs  Type Price  \
# name
# 15        3.2      55                2.7M       5,000+  Free     0
# 43        3.8    2206                1.2M     100,000+  Free     0
# 6         3.8     178                 19M      50,000+  Free     0
# 35        3.8     564                9.2M     100,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 28        3.9     136                4.6M      10,000+  Free     0
# 20        4.0     450                 14M     100,000+  Free     0
# 39        4.0     591                9.4M     500,000+  Free     0
# 27        4.1     203                6.1M     100,000+  Free     0
# 29        4.1     223                4.2M     100,000+  Free     0
# 31        4.1     227                5.2M      50,000+  Free     0
# 0         4.1     159                 19M      10,000+  Free     0
# 21        4.1     654                 12M     100,000+  Free     0
# 7         4.1   36815                 29M   1,000,000+  Free     0
# 37        4.1   36639  Varies with device   5,000,000+  Free     0
# 30        4.2    1120                9.2M     100,000+  Free     0
# 40        4.2     117                 15M      10,000+  Free     0
# 44        4.2      26                 12M      10,000+  Free     0
# 47        4.2      85                8.0M     100,000+  Free     0
# 33        4.2    1015                 11M     100,000+  Free     0
# 49        4.2     367                 25M     100,000+  Free     0
# 12        4.2   44829                 20M  10,000,000+  Free     0
# 18        4.3  194216                 39M   5,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# 48        4.3     845                7.9M     100,000+  Free     0
# 42        4.4  295221  Varies with device  10,000,000+  Free     0
# 5         4.4     167                5.6M      50,000+  Free     0
# 8         4.4   13791                 33M   1,000,000+  Free     0
# 11        4.4    8788                 12M   1,000,000+  Free     0
# 10        4.4   13880                 28M   1,000,000+  Free     0
# 14        4.4    1518                 37M     100,000+  Free     0
# 32        4.5    5035                 11M     100,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 17        4.5      27                 17M      10,000+  Free     0
# 41        4.5     176                 10M     100,000+  Free     0
# 46        4.6    1070                 26M     100,000+  Free     0
# 19        4.6  224399                 31M  10,000,000+  Free     0
# 13        4.6    4326                 21M     100,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 45        4.7  174531                 24M  10,000,000+  Free     0
# 22        4.7    7699                4.2M     500,000+  Free     0
# 26        4.7   20260                 25M     500,000+  Free     0
# 38        4.7     158                 11M      10,000+  Free     0
# 9         4.7     121                3.1M      10,000+  Free     0
# 36        4.7    8145                 24M     500,000+  Free     0
# 34        4.7     353                4.2M      10,000+  Free     0
# 16        4.7    3632                5.5M     500,000+  Free     0
# 24        4.7     118                 23M      50,000+  Free     0
# 25        4.8     192                6.0M      10,000+  Free     0
# 23        NaN      61                7.0M     100,000+  Free     0
#
# index Content Rating                           Genres        Last Updated  \
# name
# 15          Everyone                     Art & Design        June 6, 2018
# 43          Everyone          Art & Design;Creativity      April 15, 2018
# 6           Everyone                     Art & Design      April 26, 2018
# 35          Everyone                     Art & Design       July 11, 2018
# 1           Everyone        Art & Design;Pretend Play    January 15, 2018
# 28          Everyone                     Art & Design       July 12, 2018
# 20          Everyone                     Art & Design      April 20, 2018
# 39          Everyone                     Art & Design      March 31, 2018
# 27          Everyone                     Art & Design      March 21, 2018
# 29          Everyone                     Art & Design     August 22, 2017
# 31          Everyone                     Art & Design        May 31, 2018
# 0           Everyone                     Art & Design     January 7, 2018
# 21          Everyone                     Art & Design      March 20, 2018
# 7           Everyone                     Art & Design       June 14, 2018
# 37          Everyone                     Art & Design       July 14, 2018
# 30          Everyone                     Art & Design       July 12, 2018
# 40          Everyone                     Art & Design       July 20, 2018
# 44          Everyone                     Art & Design     January 3, 2018
# 47          Everyone                     Art & Design   December 17, 2017
# 33          Everyone                     Art & Design     January 6, 2018
# 49          Everyone                  Auto & Vehicles        May 10, 2018
# 12              Teen                     Art & Design       April 2, 2018
# 18          Everyone                     Art & Design      August 3, 2018
# 4           Everyone          Art & Design;Creativity       June 20, 2018
# 48          Everyone                     Art & Design        May 28, 2018
# 42          Everyone                     Art & Design       July 30, 2018
# 5           Everyone                     Art & Design      March 26, 2017
# 8           Everyone                     Art & Design  September 20, 2017
# 11          Everyone                     Art & Design       July 31, 2018
# 10          Everyone                     Art & Design    October 27, 2017
# 14          Everyone                     Art & Design      August 3, 2018
# 32          Everyone                     Art & Design       July 19, 2018
# 3               Teen                     Art & Design        June 8, 2018
# 17          Everyone                     Art & Design    November 7, 2017
# 41          Everyone                     Art & Design       April 2, 2018
# 46          Everyone                     Art & Design   November 14, 2017
# 19          Everyone                     Art & Design       July 30, 2018
# 13          Everyone                     Art & Design       June 26, 2018
# 2           Everyone                     Art & Design      August 1, 2018
# 45          Everyone                     Art & Design       July 31, 2018
# 22      Everyone 10+                     Art & Design       July 12, 2018
# 26          Everyone          Art & Design;Creativity    October 11, 2017
# 38          Everyone                     Art & Design   November 29, 2017
# 9           Everyone          Art & Design;Creativity        July 3, 2018
# 36          Everyone          Art & Design;Creativity      August 2, 2018
# 34              Teen                     Art & Design      April 27, 2018
# 16          Everyone                     Art & Design       July 31, 2018
# 24          Everyone                     Art & Design        July 7, 2018
# 25          Everyone                     Art & Design      April 25, 2018
# 23          Everyone  Art & Design;Action & Adventure       March 7, 2018
#
# index         Current Ver         Android Ver
# name
# 15                    NaN          4.2 and up
# 43                   1.46          4.1 and up
# 6                     1.1        4.0.3 and up
# 35                    2.1          4.1 and up
# 1                   2.0.0        4.0.3 and up
# 28                    6.0          2.3 and up
# 20                    4.0          4.1 and up
# 39                      1          4.0 and up
# 27                   1.03        4.0.3 and up
# 29                    1.0          2.3 and up
# 31                    1.2          2.3 and up
# 0                   1.0.0        4.0.3 and up
# 21                    1.1        4.0.3 and up
# 7                6.1.61.1          4.2 and up
# 37     Varies with device        2.3.3 and up
# 30            6.7.12.2018        4.0.3 and up
# 40                  2.0.1        4.0.3 and up
# 44                  1.0.0          4.1 and up
# 47                  2.0.0          4.1 and up
# 33                  1.1.0          4.1 and up
# 49                    1.0        4.0.3 and up
# 12                    3.8          4.1 and up
# 18                  2.2.5        4.0.3 and up
# 4                     1.1          4.4 and up
# 48                    1.0          2.3 and up
# 42     Varies with device  Varies with device
# 5                     1.0          2.3 and up
# 8                   2.9.2          3.0 and up
# 11                 1.0.15          4.0 and up
# 10                  1.0.4          4.1 and up
# 14                  1.2.3          2.3 and up
# 32                   2.20          4.0 and up
# 3      Varies with device          4.2 and up
# 17                    1.0          2.3 and up
# 41                    1.0        4.0.3 and up
# 46                    1.6          4.1 and up
# 19                  5.5.4          4.1 and up
# 13                  1.0.4          4.4 and up
# 2                   1.2.4        4.0.3 and up
# 45                  1.6.1          4.1 and up
# 22                2.2.6.2        4.0.3 and up
# 26                  1.0.8        4.0.3 and up
# 38                    1.3        4.0.3 and up
# 9                     2.8        4.0.3 and up
# 36                  1.0.9          4.4 and up
# 34                    1.6          4.1 and up
# 16                    3.1          4.1 and up
# 24                  1.1.3          4.1 and up
# 25                    1.5          3.0 and up
# 23                  1.0.0          4.1 and up

# %% [markdown]
# **데이터 선택**

# %%
# 데이터 선택 -> 특정 '컬럼'의 값 가져오기
data['App']
# Out:
# name
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                   Coloring book moana
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                 Sketch - Draw & Paint
# 4                 Pixel Draw - Number Art Coloring Book
# 5                            Paper flowers instructions
# 6               Smoke Effect Photo Maker - Smoke Editor
# 7                                      Infinite Painter
# 8                                  Garden Coloring Book
# 9                         Kids Paint Free - Drawing Fun
# 10                              Text on Photo - Fonteee
# 11              Name Art Photo Editor - Focus n Filters
# 12                       Tattoo Name On My Photo Editor
# 13                                Mandala Coloring Book
# 14      3D Color Pixel by Number - Sandbox Art Coloring
# 15                      Learn To Draw Kawaii Characters
# 16         Photo Designer - Write your name with shapes
# 17                             350 Diy Room Decor Ideas
# 18                        FlipaClip - Cartoon animation
# 19                                         ibis Paint X
# 20                          Logo Maker - Small Business
# 21            Boys Photo Editor - Six Pack & Men's Suit
# 22              Superheroes Wallpapers | 4K Backgrounds
# 23                               Mcqueen Coloring pages
# 24                          HD Mickey Minnie Wallpapers
# 25                           Harley Quinn wallpapers HD
# 26                        Colorfit - Drawing & Coloring
# 27                                Animated Photo Editor
# 28                                Pencil Sketch Drawing
# 29                      Easy Realistic Drawing Tutorial
# 30                       Pink Silver Bow Keyboard Theme
# 31                                    Art Drawing Ideas
# 32                            Anime Manga Coloring Book
# 33                                   Easy Origami Ideas
# 34                                      I Creative Idea
# 35                     How to draw Ladybug and Cat Noir
# 36       UNICORN - Color By Number & Pixel Art Coloring
# 37                                   Floor Plan Creator
# 38                       PIP Camera - PIP Collage Maker
# 39        How To Color Disney Princess - Coloring Pages
# 40                        Drawing Clothes Fashion Ideas
# 41                         Sad Poetry Photo Frames 2018
# 42                           Textgram - write on photos
# 43                                        Paint Splash!
# 44          Popsicle Sticks and Similar DIY Craft Ideas
# 45    Canva: Poster, banner, card maker & graphic de...
# 46    Install images with music to make video withou...
# 47                Little Teddy Bear Colouring Book Game
# 48                                     How To Draw Food
# 49                          Monster Truck Stunt 3D 2019
# Name: App, dtype: object

# %%
# 이하 동일. -> app 컬럼 값들만 가져옴.
data.App
# Out:
# name
# 0        Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                   Coloring book moana
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                 Sketch - Draw & Paint
# 4                 Pixel Draw - Number Art Coloring Book
# 5                            Paper flowers instructions
# 6               Smoke Effect Photo Maker - Smoke Editor
# 7                                      Infinite Painter
# 8                                  Garden Coloring Book
# 9                         Kids Paint Free - Drawing Fun
# 10                              Text on Photo - Fonteee
# 11              Name Art Photo Editor - Focus n Filters
# 12                       Tattoo Name On My Photo Editor
# 13                                Mandala Coloring Book
# 14      3D Color Pixel by Number - Sandbox Art Coloring
# 15                      Learn To Draw Kawaii Characters
# 16         Photo Designer - Write your name with shapes
# 17                             350 Diy Room Decor Ideas
# 18                        FlipaClip - Cartoon animation
# 19                                         ibis Paint X
# 20                          Logo Maker - Small Business
# 21            Boys Photo Editor - Six Pack & Men's Suit
# 22              Superheroes Wallpapers | 4K Backgrounds
# 23                               Mcqueen Coloring pages
# 24                          HD Mickey Minnie Wallpapers
# 25                           Harley Quinn wallpapers HD
# 26                        Colorfit - Drawing & Coloring
# 27                                Animated Photo Editor
# 28                                Pencil Sketch Drawing
# 29                      Easy Realistic Drawing Tutorial
# 30                       Pink Silver Bow Keyboard Theme
# 31                                    Art Drawing Ideas
# 32                            Anime Manga Coloring Book
# 33                                   Easy Origami Ideas
# 34                                      I Creative Idea
# 35                     How to draw Ladybug and Cat Noir
# 36       UNICORN - Color By Number & Pixel Art Coloring
# 37                                   Floor Plan Creator
# 38                       PIP Camera - PIP Collage Maker
# 39        How To Color Disney Princess - Coloring Pages
# 40                        Drawing Clothes Fashion Ideas
# 41                         Sad Poetry Photo Frames 2018
# 42                           Textgram - write on photos
# 43                                        Paint Splash!
# 44          Popsicle Sticks and Similar DIY Craft Ideas
# 45    Canva: Poster, banner, card maker & graphic de...
# 46    Install images with music to make video withou...
# 47                Little Teddy Bear Colouring Book Game
# 48                                     How To Draw Food
# 49                          Monster Truck Stunt 3D 2019
# Name: App, dtype: object

# %%
# 맨 처음 5개의 행을 가져온다
data[0:5]
# Out:
# index                                                App        Category  \
# name
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
# index  Rating Reviews  Size     Installs  Type Price Content Rating  \
# name
# 0         4.1     159   19M      10,000+  Free     0       Everyone
# 1         3.9     967   14M     500,000+  Free     0       Everyone
# 2         4.7   87510  8.7M   5,000,000+  Free     0       Everyone
# 3         4.5  215644   25M  50,000,000+  Free     0           Teen
# 4         4.3     967  2.8M     100,000+  Free     0       Everyone
#
# index                     Genres      Last Updated         Current Ver  \
# name
# 0                   Art & Design   January 7, 2018               1.0.0
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
#
# index   Android Ver
# name
# 0      4.0.3 and up
# 1      4.0.3 and up
# 2      4.0.3 and up
# 3        4.2 and up
# 4        4.4 and up

# %%
# index가 [12:15]에 해당하는 것만 가져온다.
data[12:15]
# Out:
# index                                              App        Category  \
# name
# 12                      Tattoo Name On My Photo Editor  ART_AND_DESIGN
# 13                               Mandala Coloring Book  ART_AND_DESIGN
# 14     3D Color Pixel by Number - Sandbox Art Coloring  ART_AND_DESIGN
#
# index  Rating Reviews Size     Installs  Type Price Content Rating  \
# name
# 12        4.2   44829  20M  10,000,000+  Free     0           Teen
# 13        4.6    4326  21M     100,000+  Free     0       Everyone
# 14        4.4    1518  37M     100,000+  Free     0       Everyone
#
# index        Genres    Last Updated Current Ver Android Ver
# name
# 12     Art & Design   April 2, 2018         3.8  4.1 and up
# 13     Art & Design   June 26, 2018       1.0.4  4.4 and up
# 14     Art & Design  August 3, 2018       1.2.3  2.3 and up

# %%
# 이름 이용 선택: loc -> 왜 안되는 것인가.
data.loc[Rating[4]]
#data.loc[App['Tattoo Name On My Photo Editor']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-bc7b960183f3> in <module>
#       1 # 이름 이용 선택: loc -> 왜 안되는 것인가.
# ----> 2 data.loc[App['Tattoo Name On My Photo Editor']]
#
# NameError: name 'App' is not defined

# %%
# 컬럼 App, Rating에 대한 모든 값 가져오기
data.loc[:,['App', 'Rating']]
# Out:
# index                                                App  Rating
# name
# 0         Photo Editor & Candy Camera & Grid & ScrapBook     4.1
# 1                                    Coloring book moana     3.9
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7
# 3                                  Sketch - Draw & Paint     4.5
# 4                  Pixel Draw - Number Art Coloring Book     4.3
# 5                             Paper flowers instructions     4.4
# 6                Smoke Effect Photo Maker - Smoke Editor     3.8
# 7                                       Infinite Painter     4.1
# 8                                   Garden Coloring Book     4.4
# 9                          Kids Paint Free - Drawing Fun     4.7
# 10                               Text on Photo - Fonteee     4.4
# 11               Name Art Photo Editor - Focus n Filters     4.4
# 12                        Tattoo Name On My Photo Editor     4.2
# 13                                 Mandala Coloring Book     4.6
# 14       3D Color Pixel by Number - Sandbox Art Coloring     4.4
# 15                       Learn To Draw Kawaii Characters     3.2
# 16          Photo Designer - Write your name with shapes     4.7
# 17                              350 Diy Room Decor Ideas     4.5
# 18                         FlipaClip - Cartoon animation     4.3
# 19                                          ibis Paint X     4.6
# 20                           Logo Maker - Small Business     4.0
# 21             Boys Photo Editor - Six Pack & Men's Suit     4.1
# 22               Superheroes Wallpapers | 4K Backgrounds     4.7
# 23                                Mcqueen Coloring pages     NaN
# 24                           HD Mickey Minnie Wallpapers     4.7
# 25                            Harley Quinn wallpapers HD     4.8
# 26                         Colorfit - Drawing & Coloring     4.7
# 27                                 Animated Photo Editor     4.1
# 28                                 Pencil Sketch Drawing     3.9
# 29                       Easy Realistic Drawing Tutorial     4.1
# 30                        Pink Silver Bow Keyboard Theme     4.2
# 31                                     Art Drawing Ideas     4.1
# 32                             Anime Manga Coloring Book     4.5
# 33                                    Easy Origami Ideas     4.2
# 34                                       I Creative Idea     4.7
# 35                      How to draw Ladybug and Cat Noir     3.8
# 36        UNICORN - Color By Number & Pixel Art Coloring     4.7
# 37                                    Floor Plan Creator     4.1
# 38                        PIP Camera - PIP Collage Maker     4.7
# 39         How To Color Disney Princess - Coloring Pages     4.0
# 40                         Drawing Clothes Fashion Ideas     4.2
# 41                          Sad Poetry Photo Frames 2018     4.5
# 42                            Textgram - write on photos     4.4
# 43                                         Paint Splash!     3.8
# 44           Popsicle Sticks and Similar DIY Craft Ideas     4.2
# 45     Canva: Poster, banner, card maker & graphic de...     4.7
# 46     Install images with music to make video withou...     4.6
# 47                 Little Teddy Bear Colouring Book Game     4.2
# 48                                      How To Draw Food     4.3
# 49                           Monster Truck Stunt 3D 2019     4.2

# %%
# 특정 인덱스 값의 컬럼 App, Rating에 대한 모든 값 가져오기
data.loc[name[5], ['App', 'Rating']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-bad332549d93> in <module>
#       1 # 특정 인덱스 값의 컬럼 App, Rating에 대한 모든 값 가져오기
# ----> 2 data.loc[name[5], ['App', 'Rating']]
#
# NameError: name 'name' is not defined

# %%
# 특정 인덱스 값과 특정 컬럼에 있는 값 가져오기 -> .at 이용  가능
data.loc[name[5],'App']
data.at[dates[5], 'App']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-c34569f0a6d6> in <module>
#       1 # 특정 인덱스 값과 특정 컬럼에 있는 값 가져오기 -> .at 이용  가능
# ----> 2 data.loc[name[5],'App']
#       3 data.at[dates[5], 'App']
#
# NameError: name 'name' is not defined

# %% [markdown]
# **위치 이용하여 선택하기**: .iloc

# %%
# python 인덱스 개념. 즉, 5번째 인덱스를 가져오는 게 아닌 6번째 인덱스 get 
data.iloc[5]
# Out:
# index
# App               Paper flowers instructions
# Category                      ART_AND_DESIGN
# Rating                                   4.4
# Reviews                                  167
# Size                                    5.6M
# Installs                             50,000+
# Type                                    Free
# Price                                      0
# Content Rating                      Everyone
# Genres                          Art & Design
# Last Updated                  March 26, 2017
# Current Ver                              1.0
# Android Ver                       2.3 and up
# Name: 5, dtype: object

# %%
# 데이터 슬라이싱 및 인덱스
data.iloc[3:5,0:2]
# Out:
# index                                    App        Category
# name
# 3                      Sketch - Draw & Paint  ART_AND_DESIGN
# 4      Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN

# %%
# 데이터 슬라이싱 및 인덱스
df.iloc[[1,2,4],[0,2]]
# Out:
# Info     name  points
# Num
# 1     Beomwoo     1.7
# 2     Beomwoo     3.6
# 4        Park     2.9

# %%
# 명시적으로 행이나 열 선택 인자에 ' : ' 있으면 -> 행 or 열 전체 가져와라
data.iloc[1:5,:]
# data.iloc[:,1:5]
# Out:
# index                                                App        Category  \
# name
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
#
# index  Rating Reviews  Size     Installs  Type Price Content Rating  \
# name
# 1         3.9     967   14M     500,000+  Free     0       Everyone
# 2         4.7   87510  8.7M   5,000,000+  Free     0       Everyone
# 3         4.5  215644   25M  50,000,000+  Free     0           Teen
# 4         4.3     967  2.8M     100,000+  Free     0       Everyone
#
# index                     Genres      Last Updated         Current Ver  \
# name
# 1      Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2                   Art & Design    August 1, 2018               1.2.4
# 3                   Art & Design      June 8, 2018  Varies with device
# 4        Art & Design;Creativity     June 20, 2018                 1.1
#
# index   Android Ver
# name
# 1      4.0.3 and up
# 2      4.0.3 and up
# 3        4.2 and up
# 4        4.4 and up

# %%
# 값 하나를 섲ㄴ택하기 위해 특정 행과 열 지정 방식. 
data.iloc[4,2]
#data.iat[4,2]
# Out:
# 4.3

# %% [markdown]
# **조건 이용 선택**

# %%
# Rating > 3.7 이상 인 데이터만 뽑음
data[data.Rating > 3.7]
# Out:
# index                                                App           Category  \
# name
# 0         Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                    Coloring book moana     ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint     ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                             Paper flowers instructions     ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                       Infinite Painter     ART_AND_DESIGN
# 8                                   Garden Coloring Book     ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                               Text on Photo - Fonteee     ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor     ART_AND_DESIGN
# 13                                 Mandala Coloring Book     ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring     ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes     ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas     ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation     ART_AND_DESIGN
# 19                                          ibis Paint X     ART_AND_DESIGN
# 20                           Logo Maker - Small Business     ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit     ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds     ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers     ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD     ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring     ART_AND_DESIGN
# 27                                 Animated Photo Editor     ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing     ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial     ART_AND_DESIGN
# 30                        Pink Silver Bow Keyboard Theme     ART_AND_DESIGN
# 31                                     Art Drawing Ideas     ART_AND_DESIGN
# 32                             Anime Manga Coloring Book     ART_AND_DESIGN
# 33                                    Easy Origami Ideas     ART_AND_DESIGN
# 34                                       I Creative Idea     ART_AND_DESIGN
# 35                      How to draw Ladybug and Cat Noir     ART_AND_DESIGN
# 36        UNICORN - Color By Number & Pixel Art Coloring     ART_AND_DESIGN
# 37                                    Floor Plan Creator     ART_AND_DESIGN
# 38                        PIP Camera - PIP Collage Maker     ART_AND_DESIGN
# 39         How To Color Disney Princess - Coloring Pages     ART_AND_DESIGN
# 40                         Drawing Clothes Fashion Ideas     ART_AND_DESIGN
# 41                          Sad Poetry Photo Frames 2018     ART_AND_DESIGN
# 42                            Textgram - write on photos     ART_AND_DESIGN
# 43                                         Paint Splash!     ART_AND_DESIGN
# 44           Popsicle Sticks and Similar DIY Craft Ideas     ART_AND_DESIGN
# 45     Canva: Poster, banner, card maker & graphic de...     ART_AND_DESIGN
# 46     Install images with music to make video withou...     ART_AND_DESIGN
# 47                 Little Teddy Bear Colouring Book Game     ART_AND_DESIGN
# 48                                      How To Draw Food     ART_AND_DESIGN
# 49                           Monster Truck Stunt 3D 2019  AUTO_AND_VEHICLES
#
# index  Rating Reviews                Size     Installs  Type Price  \
# name
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# 5         4.4     167                5.6M      50,000+  Free     0
# 6         3.8     178                 19M      50,000+  Free     0
# 7         4.1   36815                 29M   1,000,000+  Free     0
# 8         4.4   13791                 33M   1,000,000+  Free     0
# 9         4.7     121                3.1M      10,000+  Free     0
# 10        4.4   13880                 28M   1,000,000+  Free     0
# 11        4.4    8788                 12M   1,000,000+  Free     0
# 12        4.2   44829                 20M  10,000,000+  Free     0
# 13        4.6    4326                 21M     100,000+  Free     0
# 14        4.4    1518                 37M     100,000+  Free     0
# 16        4.7    3632                5.5M     500,000+  Free     0
# 17        4.5      27                 17M      10,000+  Free     0
# 18        4.3  194216                 39M   5,000,000+  Free     0
# 19        4.6  224399                 31M  10,000,000+  Free     0
# 20        4.0     450                 14M     100,000+  Free     0
# 21        4.1     654                 12M     100,000+  Free     0
# 22        4.7    7699                4.2M     500,000+  Free     0
# 24        4.7     118                 23M      50,000+  Free     0
# 25        4.8     192                6.0M      10,000+  Free     0
# 26        4.7   20260                 25M     500,000+  Free     0
# 27        4.1     203                6.1M     100,000+  Free     0
# 28        3.9     136                4.6M      10,000+  Free     0
# 29        4.1     223                4.2M     100,000+  Free     0
# 30        4.2    1120                9.2M     100,000+  Free     0
# 31        4.1     227                5.2M      50,000+  Free     0
# 32        4.5    5035                 11M     100,000+  Free     0
# 33        4.2    1015                 11M     100,000+  Free     0
# 34        4.7     353                4.2M      10,000+  Free     0
# 35        3.8     564                9.2M     100,000+  Free     0
# 36        4.7    8145                 24M     500,000+  Free     0
# 37        4.1   36639  Varies with device   5,000,000+  Free     0
# 38        4.7     158                 11M      10,000+  Free     0
# 39        4.0     591                9.4M     500,000+  Free     0
# 40        4.2     117                 15M      10,000+  Free     0
# 41        4.5     176                 10M     100,000+  Free     0
# 42        4.4  295221  Varies with device  10,000,000+  Free     0
# 43        3.8    2206                1.2M     100,000+  Free     0
# 44        4.2      26                 12M      10,000+  Free     0
# 45        4.7  174531                 24M  10,000,000+  Free     0
# 46        4.6    1070                 26M     100,000+  Free     0
# 47        4.2      85                8.0M     100,000+  Free     0
# 48        4.3     845                7.9M     100,000+  Free     0
# 49        4.2     367                 25M     100,000+  Free     0
#
# index Content Rating                     Genres        Last Updated  \
# name
# 0           Everyone               Art & Design     January 7, 2018
# 1           Everyone  Art & Design;Pretend Play    January 15, 2018
# 2           Everyone               Art & Design      August 1, 2018
# 3               Teen               Art & Design        June 8, 2018
# 4           Everyone    Art & Design;Creativity       June 20, 2018
# 5           Everyone               Art & Design      March 26, 2017
# 6           Everyone               Art & Design      April 26, 2018
# 7           Everyone               Art & Design       June 14, 2018
# 8           Everyone               Art & Design  September 20, 2017
# 9           Everyone    Art & Design;Creativity        July 3, 2018
# 10          Everyone               Art & Design    October 27, 2017
# 11          Everyone               Art & Design       July 31, 2018
# 12              Teen               Art & Design       April 2, 2018
# 13          Everyone               Art & Design       June 26, 2018
# 14          Everyone               Art & Design      August 3, 2018
# 16          Everyone               Art & Design       July 31, 2018
# 17          Everyone               Art & Design    November 7, 2017
# 18          Everyone               Art & Design      August 3, 2018
# 19          Everyone               Art & Design       July 30, 2018
# 20          Everyone               Art & Design      April 20, 2018
# 21          Everyone               Art & Design      March 20, 2018
# 22      Everyone 10+               Art & Design       July 12, 2018
# 24          Everyone               Art & Design        July 7, 2018
# 25          Everyone               Art & Design      April 25, 2018
# 26          Everyone    Art & Design;Creativity    October 11, 2017
# 27          Everyone               Art & Design      March 21, 2018
# 28          Everyone               Art & Design       July 12, 2018
# 29          Everyone               Art & Design     August 22, 2017
# 30          Everyone               Art & Design       July 12, 2018
# 31          Everyone               Art & Design        May 31, 2018
# 32          Everyone               Art & Design       July 19, 2018
# 33          Everyone               Art & Design     January 6, 2018
# 34              Teen               Art & Design      April 27, 2018
# 35          Everyone               Art & Design       July 11, 2018
# 36          Everyone    Art & Design;Creativity      August 2, 2018
# 37          Everyone               Art & Design       July 14, 2018
# 38          Everyone               Art & Design   November 29, 2017
# 39          Everyone               Art & Design      March 31, 2018
# 40          Everyone               Art & Design       July 20, 2018
# 41          Everyone               Art & Design       April 2, 2018
# 42          Everyone               Art & Design       July 30, 2018
# 43          Everyone    Art & Design;Creativity      April 15, 2018
# 44          Everyone               Art & Design     January 3, 2018
# 45          Everyone               Art & Design       July 31, 2018
# 46          Everyone               Art & Design   November 14, 2017
# 47          Everyone               Art & Design   December 17, 2017
# 48          Everyone               Art & Design        May 28, 2018
# 49          Everyone            Auto & Vehicles        May 10, 2018
#
# index         Current Ver         Android Ver
# name
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# 5                     1.0          2.3 and up
# 6                     1.1        4.0.3 and up
# 7                6.1.61.1          4.2 and up
# 8                   2.9.2          3.0 and up
# 9                     2.8        4.0.3 and up
# 10                  1.0.4          4.1 and up
# 11                 1.0.15          4.0 and up
# 12                    3.8          4.1 and up
# 13                  1.0.4          4.4 and up
# 14                  1.2.3          2.3 and up
# 16                    3.1          4.1 and up
# 17                    1.0          2.3 and up
# 18                  2.2.5        4.0.3 and up
# 19                  5.5.4          4.1 and up
# 20                    4.0          4.1 and up
# 21                    1.1        4.0.3 and up
# 22                2.2.6.2        4.0.3 and up
# 24                  1.1.3          4.1 and up
# 25                    1.5          3.0 and up
# 26                  1.0.8        4.0.3 and up
# 27                   1.03        4.0.3 and up
# 28                    6.0          2.3 and up
# 29                    1.0          2.3 and up
# 30            6.7.12.2018        4.0.3 and up
# 31                    1.2          2.3 and up
# 32                   2.20          4.0 and up
# 33                  1.1.0          4.1 and up
# 34                    1.6          4.1 and up
# 35                    2.1          4.1 and up
# 36                  1.0.9          4.4 and up
# 37     Varies with device        2.3.3 and up
# 38                    1.3        4.0.3 and up
# 39                      1          4.0 and up
# 40                  2.0.1        4.0.3 and up
# 41                    1.0        4.0.3 and up
# 42     Varies with device  Varies with device
# 43                   1.46          4.1 and up
# 44                  1.0.0          4.1 and up
# 45                  1.6.1          4.1 and up
# 46                    1.6          4.1 and up
# 47                  2.0.0          4.1 and up
# 48                    1.0          2.3 and up
# 49                    1.0        4.0.3 and up

# %% [markdown]
# **데이터 변경하기**
#
# 데이터 프레임 특정 값들을 다른 값으로 변경 할 수 있다.
#
# 기존 데이터 프레임에 새로운 열을 추가하고 싶을 때는 다음과 같이 같은 인덱스를 가진 시리즈 하나를 데이터 프레임 열 하나를 지정하여 넣어준다

# %%
# 값 알맞게 찾아서 넣기. 
test = pd.Series(['Photo Editor', 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))

# %%
test
# Out:
# 2013-01-02    Photo Editor
# 2013-01-03               2
# 2013-01-04               3
# 2013-01-05               4
# 2013-01-06               5
# 2013-01-07               6
# Freq: D, dtype: object

# %%
data['F'] = test

# %%
data
# Out:
# index                                                App           Category  \
# name
# 0         Photo Editor & Candy Camera & Grid & ScrapBook     ART_AND_DESIGN
# 1                                    Coloring book moana     ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...     ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint     ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book     ART_AND_DESIGN
# 5                             Paper flowers instructions     ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor     ART_AND_DESIGN
# 7                                       Infinite Painter     ART_AND_DESIGN
# 8                                   Garden Coloring Book     ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun     ART_AND_DESIGN
# 10                               Text on Photo - Fonteee     ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters     ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor     ART_AND_DESIGN
# 13                                 Mandala Coloring Book     ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring     ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters     ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes     ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas     ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation     ART_AND_DESIGN
# 19                                          ibis Paint X     ART_AND_DESIGN
# 20                           Logo Maker - Small Business     ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit     ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds     ART_AND_DESIGN
# 23                                Mcqueen Coloring pages     ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers     ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD     ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring     ART_AND_DESIGN
# 27                                 Animated Photo Editor     ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing     ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial     ART_AND_DESIGN
# 30                        Pink Silver Bow Keyboard Theme     ART_AND_DESIGN
# 31                                     Art Drawing Ideas     ART_AND_DESIGN
# 32                             Anime Manga Coloring Book     ART_AND_DESIGN
# 33                                    Easy Origami Ideas     ART_AND_DESIGN
# 34                                       I Creative Idea     ART_AND_DESIGN
# 35                      How to draw Ladybug and Cat Noir     ART_AND_DESIGN
# 36        UNICORN - Color By Number & Pixel Art Coloring     ART_AND_DESIGN
# 37                                    Floor Plan Creator     ART_AND_DESIGN
# 38                        PIP Camera - PIP Collage Maker     ART_AND_DESIGN
# 39         How To Color Disney Princess - Coloring Pages     ART_AND_DESIGN
# 40                         Drawing Clothes Fashion Ideas     ART_AND_DESIGN
# 41                          Sad Poetry Photo Frames 2018     ART_AND_DESIGN
# 42                            Textgram - write on photos     ART_AND_DESIGN
# 43                                         Paint Splash!     ART_AND_DESIGN
# 44           Popsicle Sticks and Similar DIY Craft Ideas     ART_AND_DESIGN
# 45     Canva: Poster, banner, card maker & graphic de...     ART_AND_DESIGN
# 46     Install images with music to make video withou...     ART_AND_DESIGN
# 47                 Little Teddy Bear Colouring Book Game     ART_AND_DESIGN
# 48                                      How To Draw Food     ART_AND_DESIGN
# 49                           Monster Truck Stunt 3D 2019  AUTO_AND_VEHICLES
#
# index  Rating Reviews                Size     Installs  Type Price  \
# name
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# 5         4.4     167                5.6M      50,000+  Free     0
# 6         3.8     178                 19M      50,000+  Free     0
# 7         4.1   36815                 29M   1,000,000+  Free     0
# 8         4.4   13791                 33M   1,000,000+  Free     0
# 9         4.7     121                3.1M      10,000+  Free     0
# 10        4.4   13880                 28M   1,000,000+  Free     0
# 11        4.4    8788                 12M   1,000,000+  Free     0
# 12        4.2   44829                 20M  10,000,000+  Free     0
# 13        4.6    4326                 21M     100,000+  Free     0
# 14        4.4    1518                 37M     100,000+  Free     0
# 15        3.2      55                2.7M       5,000+  Free     0
# 16        4.7    3632                5.5M     500,000+  Free     0
# 17        4.5      27                 17M      10,000+  Free     0
# 18        4.3  194216                 39M   5,000,000+  Free     0
# 19        4.6  224399                 31M  10,000,000+  Free     0
# 20        4.0     450                 14M     100,000+  Free     0
# 21        4.1     654                 12M     100,000+  Free     0
# 22        4.7    7699                4.2M     500,000+  Free     0
# 23        NaN      61                7.0M     100,000+  Free     0
# 24        4.7     118                 23M      50,000+  Free     0
# 25        4.8     192                6.0M      10,000+  Free     0
# 26        4.7   20260                 25M     500,000+  Free     0
# 27        4.1     203                6.1M     100,000+  Free     0
# 28        3.9     136                4.6M      10,000+  Free     0
# 29        4.1     223                4.2M     100,000+  Free     0
# 30        4.2    1120                9.2M     100,000+  Free     0
# 31        4.1     227                5.2M      50,000+  Free     0
# 32        4.5    5035                 11M     100,000+  Free     0
# 33        4.2    1015                 11M     100,000+  Free     0
# 34        4.7     353                4.2M      10,000+  Free     0
# 35        3.8     564                9.2M     100,000+  Free     0
# 36        4.7    8145                 24M     500,000+  Free     0
# 37        4.1   36639  Varies with device   5,000,000+  Free     0
# 38        4.7     158                 11M      10,000+  Free     0
# 39        4.0     591                9.4M     500,000+  Free     0
# 40        4.2     117                 15M      10,000+  Free     0
# 41        4.5     176                 10M     100,000+  Free     0
# 42        4.4  295221  Varies with device  10,000,000+  Free     0
# 43        3.8    2206                1.2M     100,000+  Free     0
# 44        4.2      26                 12M      10,000+  Free     0
# 45        4.7  174531                 24M  10,000,000+  Free     0
# 46        4.6    1070                 26M     100,000+  Free     0
# 47        4.2      85                8.0M     100,000+  Free     0
# 48        4.3     845                7.9M     100,000+  Free     0
# 49        4.2     367                 25M     100,000+  Free     0
#
# index Content Rating                           Genres        Last Updated  \
# name
# 0           Everyone                     Art & Design     January 7, 2018
# 1           Everyone        Art & Design;Pretend Play    January 15, 2018
# 2           Everyone                     Art & Design      August 1, 2018
# 3               Teen                     Art & Design        June 8, 2018
# 4           Everyone          Art & Design;Creativity       June 20, 2018
# 5           Everyone                     Art & Design      March 26, 2017
# 6           Everyone                     Art & Design      April 26, 2018
# 7           Everyone                     Art & Design       June 14, 2018
# 8           Everyone                     Art & Design  September 20, 2017
# 9           Everyone          Art & Design;Creativity        July 3, 2018
# 10          Everyone                     Art & Design    October 27, 2017
# 11          Everyone                     Art & Design       July 31, 2018
# 12              Teen                     Art & Design       April 2, 2018
# 13          Everyone                     Art & Design       June 26, 2018
# 14          Everyone                     Art & Design      August 3, 2018
# 15          Everyone                     Art & Design        June 6, 2018
# 16          Everyone                     Art & Design       July 31, 2018
# 17          Everyone                     Art & Design    November 7, 2017
# 18          Everyone                     Art & Design      August 3, 2018
# 19          Everyone                     Art & Design       July 30, 2018
# 20          Everyone                     Art & Design      April 20, 2018
# 21          Everyone                     Art & Design      March 20, 2018
# 22      Everyone 10+                     Art & Design       July 12, 2018
# 23          Everyone  Art & Design;Action & Adventure       March 7, 2018
# 24          Everyone                     Art & Design        July 7, 2018
# 25          Everyone                     Art & Design      April 25, 2018
# 26          Everyone          Art & Design;Creativity    October 11, 2017
# 27          Everyone                     Art & Design      March 21, 2018
# 28          Everyone                     Art & Design       July 12, 2018
# 29          Everyone                     Art & Design     August 22, 2017
# 30          Everyone                     Art & Design       July 12, 2018
# 31          Everyone                     Art & Design        May 31, 2018
# 32          Everyone                     Art & Design       July 19, 2018
# 33          Everyone                     Art & Design     January 6, 2018
# 34              Teen                     Art & Design      April 27, 2018
# 35          Everyone                     Art & Design       July 11, 2018
# 36          Everyone          Art & Design;Creativity      August 2, 2018
# 37          Everyone                     Art & Design       July 14, 2018
# 38          Everyone                     Art & Design   November 29, 2017
# 39          Everyone                     Art & Design      March 31, 2018
# 40          Everyone                     Art & Design       July 20, 2018
# 41          Everyone                     Art & Design       April 2, 2018
# 42          Everyone                     Art & Design       July 30, 2018
# 43          Everyone          Art & Design;Creativity      April 15, 2018
# 44          Everyone                     Art & Design     January 3, 2018
# 45          Everyone                     Art & Design       July 31, 2018
# 46          Everyone                     Art & Design   November 14, 2017
# 47          Everyone                     Art & Design   December 17, 2017
# 48          Everyone                     Art & Design        May 28, 2018
# 49          Everyone                  Auto & Vehicles        May 10, 2018
#
# index         Current Ver         Android Ver    F
# name
# 0                   1.0.0        4.0.3 and up  NaN
# 1                   2.0.0        4.0.3 and up  NaN
# 2                   1.2.4        4.0.3 and up  NaN
# 3      Varies with device          4.2 and up  NaN
# 4                     1.1          4.4 and up  NaN
# 5                     1.0          2.3 and up  NaN
# 6                     1.1        4.0.3 and up  NaN
# 7                6.1.61.1          4.2 and up  NaN
# 8                   2.9.2          3.0 and up  NaN
# 9                     2.8        4.0.3 and up  NaN
# 10                  1.0.4          4.1 and up  NaN
# 11                 1.0.15          4.0 and up  NaN
# 12                    3.8          4.1 and up  NaN
# 13                  1.0.4          4.4 and up  NaN
# 14                  1.2.3          2.3 and up  NaN
# 15                    NaN          4.2 and up  NaN
# 16                    3.1          4.1 and up  NaN
# 17                    1.0          2.3 and up  NaN
# 18                  2.2.5        4.0.3 and up  NaN
# 19                  5.5.4          4.1 and up  NaN
# 20                    4.0          4.1 and up  NaN
# 21                    1.1        4.0.3 and up  NaN
# 22                2.2.6.2        4.0.3 and up  NaN
# 23                  1.0.0          4.1 and up  NaN
# 24                  1.1.3          4.1 and up  NaN
# 25                    1.5          3.0 and up  NaN
# 26                  1.0.8        4.0.3 and up  NaN
# 27                   1.03        4.0.3 and up  NaN
# 28                    6.0          2.3 and up  NaN
# 29                    1.0          2.3 and up  NaN
# 30            6.7.12.2018        4.0.3 and up  NaN
# 31                    1.2          2.3 and up  NaN
# 32                   2.20          4.0 and up  NaN
# 33                  1.1.0          4.1 and up  NaN
# 34                    1.6          4.1 and up  NaN
# 35                    2.1          4.1 and up  NaN
# 36                  1.0.9          4.4 and up  NaN
# 37     Varies with device        2.3.3 and up  NaN
# 38                    1.3        4.0.3 and up  NaN
# 39                      1          4.0 and up  NaN
# 40                  2.0.1        4.0.3 and up  NaN
# 41                    1.0        4.0.3 and up  NaN
# 42     Varies with device  Varies with device  NaN
# 43                   1.46          4.1 and up  NaN
# 44                  1.0.0          4.1 and up  NaN
# 45                  1.6.1          4.1 and up  NaN
# 46                    1.6          4.1 and up  NaN
# 47                  2.0.0          4.1 and up  NaN
# 48                    1.0          2.3 and up  NaN
# 49                    1.0        4.0.3 and up  NaN

# %%
# 데이터 프레임의 특정 값 하나를 선택하여 다른 값으로 변경. -> 넌 또 왜 안돼.
data.at[name[0], 'APP'] = 3.7
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-b47faaed05db> in <module>
#       1 # 데이터 프레임의 특정 값 하나를 선택하여 다른 값으로 변경.
# ----> 2 data.at[name[0], 'APP'] = 3.7
#
# NameError: name 'name' is not defined

# %%
# 값의 위치(인덱스 번호)를 이용한 변경 가능
data.iat[0,4] = 3.7

# %%
# 데이터 내용 한꺼번에 바꾸기 -> 어떻게 변경 되었는가
data.loc[:,'App'] = np.array([5] * len(data))

# %%
data
# Out:
# index  App           Category  Rating Reviews                Size  \
# name
# 0        5     ART_AND_DESIGN     4.1     159                 4.4
# 1        5     ART_AND_DESIGN     3.9     967                 14M
# 2        5     ART_AND_DESIGN     4.7   87510                8.7M
# 3        5     ART_AND_DESIGN     4.5  215644                 25M
# 4        5     ART_AND_DESIGN     4.3     967                2.8M
# 5        5     ART_AND_DESIGN     4.4     167                5.6M
# 6        5     ART_AND_DESIGN     3.8     178                 19M
# 7        5     ART_AND_DESIGN     4.1   36815                 29M
# 8        5     ART_AND_DESIGN     4.4   13791                 33M
# 9        5     ART_AND_DESIGN     4.7     121                3.1M
# 10       5     ART_AND_DESIGN     4.4   13880                 28M
# 11       5     ART_AND_DESIGN     4.4    8788                 12M
# 12       5     ART_AND_DESIGN     4.2   44829                 20M
# 13       5     ART_AND_DESIGN     4.6    4326                 21M
# 14       5     ART_AND_DESIGN     4.4    1518                 37M
# 15       5     ART_AND_DESIGN     3.2      55                2.7M
# 16       5     ART_AND_DESIGN     4.7    3632                5.5M
# 17       5     ART_AND_DESIGN     4.5      27                 17M
# 18       5     ART_AND_DESIGN     4.3  194216                 39M
# 19       5     ART_AND_DESIGN     4.6  224399                 31M
# 20       5     ART_AND_DESIGN     4.0     450                 14M
# 21       5     ART_AND_DESIGN     4.1     654                 12M
# 22       5     ART_AND_DESIGN     4.7    7699                4.2M
# 23       5     ART_AND_DESIGN     NaN      61                7.0M
# 24       5     ART_AND_DESIGN     4.7     118                 23M
# 25       5     ART_AND_DESIGN     4.8     192                6.0M
# 26       5     ART_AND_DESIGN     4.7   20260                 25M
# 27       5     ART_AND_DESIGN     4.1     203                6.1M
# 28       5     ART_AND_DESIGN     3.9     136                4.6M
# 29       5     ART_AND_DESIGN     4.1     223                4.2M
# 30       5     ART_AND_DESIGN     4.2    1120                9.2M
# 31       5     ART_AND_DESIGN     4.1     227                5.2M
# 32       5     ART_AND_DESIGN     4.5    5035                 11M
# 33       5     ART_AND_DESIGN     4.2    1015                 11M
# 34       5     ART_AND_DESIGN     4.7     353                4.2M
# 35       5     ART_AND_DESIGN     3.8     564                9.2M
# 36       5     ART_AND_DESIGN     4.7    8145                 24M
# 37       5     ART_AND_DESIGN     4.1   36639  Varies with device
# 38       5     ART_AND_DESIGN     4.7     158                 11M
# 39       5     ART_AND_DESIGN     4.0     591                9.4M
# 40       5     ART_AND_DESIGN     4.2     117                 15M
# 41       5     ART_AND_DESIGN     4.5     176                 10M
# 42       5     ART_AND_DESIGN     4.4  295221  Varies with device
# 43       5     ART_AND_DESIGN     3.8    2206                1.2M
# 44       5     ART_AND_DESIGN     4.2      26                 12M
# 45       5     ART_AND_DESIGN     4.7  174531                 24M
# 46       5     ART_AND_DESIGN     4.6    1070                 26M
# 47       5     ART_AND_DESIGN     4.2      85                8.0M
# 48       5     ART_AND_DESIGN     4.3     845                7.9M
# 49       5  AUTO_AND_VEHICLES     4.2     367                 25M
#
# index     Installs  Type Price Content Rating  \
# name
# 0          10,000+  Free     0       Everyone
# 1         500,000+  Free     0       Everyone
# 2       5,000,000+  Free     0       Everyone
# 3      50,000,000+  Free     0           Teen
# 4         100,000+  Free     0       Everyone
# 5          50,000+  Free     0       Everyone
# 6          50,000+  Free     0       Everyone
# 7       1,000,000+  Free     0       Everyone
# 8       1,000,000+  Free     0       Everyone
# 9          10,000+  Free     0       Everyone
# 10      1,000,000+  Free     0       Everyone
# 11      1,000,000+  Free     0       Everyone
# 12     10,000,000+  Free     0           Teen
# 13        100,000+  Free     0       Everyone
# 14        100,000+  Free     0       Everyone
# 15          5,000+  Free     0       Everyone
# 16        500,000+  Free     0       Everyone
# 17         10,000+  Free     0       Everyone
# 18      5,000,000+  Free     0       Everyone
# 19     10,000,000+  Free     0       Everyone
# 20        100,000+  Free     0       Everyone
# 21        100,000+  Free     0       Everyone
# 22        500,000+  Free     0   Everyone 10+
# 23        100,000+  Free     0       Everyone
# 24         50,000+  Free     0       Everyone
# 25         10,000+  Free     0       Everyone
# 26        500,000+  Free     0       Everyone
# 27        100,000+  Free     0       Everyone
# 28         10,000+  Free     0       Everyone
# 29        100,000+  Free     0       Everyone
# 30        100,000+  Free     0       Everyone
# 31         50,000+  Free     0       Everyone
# 32        100,000+  Free     0       Everyone
# 33        100,000+  Free     0       Everyone
# 34         10,000+  Free     0           Teen
# 35        100,000+  Free     0       Everyone
# 36        500,000+  Free     0       Everyone
# 37      5,000,000+  Free     0       Everyone
# 38         10,000+  Free     0       Everyone
# 39        500,000+  Free     0       Everyone
# 40         10,000+  Free     0       Everyone
# 41        100,000+  Free     0       Everyone
# 42     10,000,000+  Free     0       Everyone
# 43        100,000+  Free     0       Everyone
# 44         10,000+  Free     0       Everyone
# 45     10,000,000+  Free     0       Everyone
# 46        100,000+  Free     0       Everyone
# 47        100,000+  Free     0       Everyone
# 48        100,000+  Free     0       Everyone
# 49        100,000+  Free     0       Everyone
#
# index                           Genres        Last Updated  \
# name
# 0                         Art & Design     January 7, 2018
# 1            Art & Design;Pretend Play    January 15, 2018
# 2                         Art & Design      August 1, 2018
# 3                         Art & Design        June 8, 2018
# 4              Art & Design;Creativity       June 20, 2018
# 5                         Art & Design      March 26, 2017
# 6                         Art & Design      April 26, 2018
# 7                         Art & Design       June 14, 2018
# 8                         Art & Design  September 20, 2017
# 9              Art & Design;Creativity        July 3, 2018
# 10                        Art & Design    October 27, 2017
# 11                        Art & Design       July 31, 2018
# 12                        Art & Design       April 2, 2018
# 13                        Art & Design       June 26, 2018
# 14                        Art & Design      August 3, 2018
# 15                        Art & Design        June 6, 2018
# 16                        Art & Design       July 31, 2018
# 17                        Art & Design    November 7, 2017
# 18                        Art & Design      August 3, 2018
# 19                        Art & Design       July 30, 2018
# 20                        Art & Design      April 20, 2018
# 21                        Art & Design      March 20, 2018
# 22                        Art & Design       July 12, 2018
# 23     Art & Design;Action & Adventure       March 7, 2018
# 24                        Art & Design        July 7, 2018
# 25                        Art & Design      April 25, 2018
# 26             Art & Design;Creativity    October 11, 2017
# 27                        Art & Design      March 21, 2018
# 28                        Art & Design       July 12, 2018
# 29                        Art & Design     August 22, 2017
# 30                        Art & Design       July 12, 2018
# 31                        Art & Design        May 31, 2018
# 32                        Art & Design       July 19, 2018
# 33                        Art & Design     January 6, 2018
# 34                        Art & Design      April 27, 2018
# 35                        Art & Design       July 11, 2018
# 36             Art & Design;Creativity      August 2, 2018
# 37                        Art & Design       July 14, 2018
# 38                        Art & Design   November 29, 2017
# 39                        Art & Design      March 31, 2018
# 40                        Art & Design       July 20, 2018
# 41                        Art & Design       April 2, 2018
# 42                        Art & Design       July 30, 2018
# 43             Art & Design;Creativity      April 15, 2018
# 44                        Art & Design     January 3, 2018
# 45                        Art & Design       July 31, 2018
# 46                        Art & Design   November 14, 2017
# 47                        Art & Design   December 17, 2017
# 48                        Art & Design        May 28, 2018
# 49                     Auto & Vehicles        May 10, 2018
#
# index         Current Ver         Android Ver    F
# name
# 0                   1.0.0        4.0.3 and up  NaN
# 1                   2.0.0        4.0.3 and up  NaN
# 2                   1.2.4        4.0.3 and up  NaN
# 3      Varies with device          4.2 and up  NaN
# 4                     1.1          4.4 and up  NaN
# 5                     1.0          2.3 and up  NaN
# 6                     1.1        4.0.3 and up  NaN
# 7                6.1.61.1          4.2 and up  NaN
# 8                   2.9.2          3.0 and up  NaN
# 9                     2.8        4.0.3 and up  NaN
# 10                  1.0.4          4.1 and up  NaN
# 11                 1.0.15          4.0 and up  NaN
# 12                    3.8          4.1 and up  NaN
# 13                  1.0.4          4.4 and up  NaN
# 14                  1.2.3          2.3 and up  NaN
# 15                    NaN          4.2 and up  NaN
# 16                    3.1          4.1 and up  NaN
# 17                    1.0          2.3 and up  NaN
# 18                  2.2.5        4.0.3 and up  NaN
# 19                  5.5.4          4.1 and up  NaN
# 20                    4.0          4.1 and up  NaN
# 21                    1.1        4.0.3 and up  NaN
# 22                2.2.6.2        4.0.3 and up  NaN
# 23                  1.0.0          4.1 and up  NaN
# 24                  1.1.3          4.1 and up  NaN
# 25                    1.5          3.0 and up  NaN
# 26                  1.0.8        4.0.3 and up  NaN
# 27                   1.03        4.0.3 and up  NaN
# 28                    6.0          2.3 and up  NaN
# 29                    1.0          2.3 and up  NaN
# 30            6.7.12.2018        4.0.3 and up  NaN
# 31                    1.2          2.3 and up  NaN
# 32                   2.20          4.0 and up  NaN
# 33                  1.1.0          4.1 and up  NaN
# 34                    1.6          4.1 and up  NaN
# 35                    2.1          4.1 and up  NaN
# 36                  1.0.9          4.4 and up  NaN
# 37     Varies with device        2.3.3 and up  NaN
# 38                    1.3        4.0.3 and up  NaN
# 39                      1          4.0 and up  NaN
# 40                  2.0.1        4.0.3 and up  NaN
# 41                    1.0        4.0.3 and up  NaN
# 42     Varies with device  Varies with device  NaN
# 43                   1.46          4.1 and up  NaN
# 44                  1.0.0          4.1 and up  NaN
# 45                  1.6.1          4.1 and up  NaN
# 46                    1.6          4.1 and up  NaN
# 47                  2.0.0          4.1 and up  NaN
# 48                    1.0          2.3 and up  NaN
# 49                    1.0        4.0.3 and up  NaN
